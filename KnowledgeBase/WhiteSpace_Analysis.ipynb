# %%
import os
import string

import PyPDF2
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')

from gensim.models import Word2Vec
import umap

import holoviews as hv
import datashader as ds
from holoviews.operation.datashader import datashade, spread
from bokeh.models import HoverTool
hv.extension('bokeh')

import plotly.graph_objs as go
# Out:
# d:\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# d:\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# d:\Anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shutt\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
def extract_text_from_pdf(file_path):
    pdf_file = open(file_path, 'rb')
    read_pdf = PyPDF2.PdfReader(pdf_file)
    number_of_pages = len(read_pdf.pages)
    text = ""
    for page_number in range(number_of_pages):
        page = read_pdf.pages[page_number]
        page_content = page.extract_text ()
        text += page_content
    return text

def get_sentences_from_dir(directory):
    all_sentences = []
    for filename in os.listdir(directory):
        if filename.endswith(".pdf"):
            text = extract_text_from_pdf(os.path.join(directory, filename))
            sentences = sent_tokenize(text)
            all_sentences.extend(sentences)
    return all_sentences

def process_text(sentences):
    table = str.maketrans('', '', string.punctuation)
    processed_text = []
    for sentence in sentences:
        tokens = word_tokenize(sentence)
        tokens = [w.lower() for w in tokens]
        stripped = [w.translate(table) for w in tokens]
        words = [word for word in stripped if word.isalpha()]
        processed_text.append(words)
    return processed_text

def remove_punctuation(sentence):
    # Create a translation table mapping every punctuation character to None
    translator = str.maketrans('', '', string.punctuation)
    
    # Use the table to remove all punctuation from the sentence
    no_punct = sentence.translate(translator)
    return no_punct

# %%
directory_path = "D:\\repos\\urtec\\2023"
sentences = get_sentences_from_dir(directory_path)
processed_text = process_text(sentences)
processed_text
# Out:
# [['urtec',
#   'gas',
#   'hydrate',
#   'structure',
#   'evolution',
#   'revealed',
#   'by',
#   'coarsening',
#   'molecular',
#   'dynamics',
#   'simulation',
#   'hao',
#   'xiong',
#   'hao',
#   'jing'],
#  [],
#  ['yale', 'university'],
#  ['hohai'],
#  ['colorado',
#   'school',
#   'of',
#   'mines',
#   'copyright',
#   'unconventional',
#   'resources',
#   'technology',
#   'conference',
#   'urtec',
#   'doi',
#   'this',
#   'paper',
#   'was',
#   'prepared',
#   'for',
#   'presentation',
#   'at',
#   'the',
#   'unconventional',
#   'resources',
#   'technology',
#   'conference',
#   'held',
#   'in',
#   'denver',
#   'colorado',
#   'usa',
#   'june'],
#  ['the',
#   'urtec',
#   'technical',
#   'program',
#   'committee',
#   'accepted',
#   'this',
#   'presentation',
#   'on',
#   'the',
#   'basis',
#   'of',
#   'information',
#   'contained',
#   'in',
#   'an',
#   'abstract',
#   'submitted',
#   'by',
#   'the',
#   'author',
#   's'],
#  ['the',
#   'contents',
#   'of',
#   'this',
#   'paper',
#   'have',
#   'not',
#   'been',
#   'reviewed',
#   'by',
#   'urtec',
#   'and',
#   'urtec',
#   'does',
#   'not',
#   'warrant',
#   'the',
#   'accuracy',
#   'reliability',
#   'or',
#   'timeliness',
#   'of',
#   'any',
#   'information',
#   'herein'],
#  ['all',
#   'information',
#   'is',
#   'the',
#   'responsibility',
#   'of',
#   'and',
#   'is',
#   'subject',
#   'to',
#   'corrections',
#   'by',
#   'the',
#   'author',
#   's'],
#  ['any',
#   'person',
#   'or',
#   'entity',
#   'that',
#   'relies',
#   'on',
#   'any',
#   'information',
#   'obtained',
#   'from',
#   'this',
#   'paper',
#   'does',
#   'so',
#   'at',
#   'their',
#   'own',
#   'risk'],
#  ['the',
#   'information',
#   'herein',
#   'does',
#   'not',
#   'necessarily',
#   'reflect',
#   'any',
#   'position',
#   'of',
#   'urtec'],
#  ['any',
#   'reproduction',
#   'distribution',
#   'or',
#   'storage',
#   'of',
#   'any',
#   'part',
#   'of',
#   'this',
#   'paper',
#   'by',
#   'anyone',
#   'other',
#   'than',
#   'the',
#   'author',
#   'without',
#   'the',
#   'written',
#   'consent',
#   'of',
#   'urtec',
#   'is',
#   'prohibited'],
#  ['abstract',
#   'hydrate',
#   'has',
#   'great',
#   'application',
#   'prospects',
#   'in',
#   'being',
#   'an',
#   'energystoragereleasing',
#   'medium',
#   'the',
#   'lowcost',
#   'fixation',
#   'and',
#   'efficient',
#   'oilgas',
#   'transmission'],
#  ['a',
#   'deep',
#   'understanding',
#   'of',
#   'the',
#   'evolution',
#   'path',
#   'of',
#   'hydrate',
#   'formation',
#   'is',
#   'currently',
#   'one',
#   'of',
#   'the',
#   'most',
#   'important',
#   'thresholds',
#   'for',
#   'these',
#   'applications'],
#  ['in',
#   'this',
#   'study',
#   'methane',
#   'hydrate',
#   'also',
#   'known',
#   'as',
#   'natural',
#   'gas',
#   'hydrate',
#   'ngh',
#   'a',
#   'kind',
#   'of',
#   'clean',
#   'energy',
#   'and',
#   'one',
#   'of',
#   'the',
#   'most',
#   'widespread',
#   'hydrate',
#   'clathrates',
#   'on',
#   'earth',
#   'is',
#   'selected',
#   'as',
#   'the',
#   'research',
#   'object'],
#  ['before',
#   'the',
#   'analysis',
#   'the',
#   'trajectories',
#   'of',
#   'the',
#   'hydrate',
#   'growth',
#   'are',
#   'obtained',
#   'by',
#   'using',
#   'molecular',
#   'dynamics',
#   'md',
#   'simulations'],
#  ['then',
#   'the',
#   'trajectories',
#   'of',
#   'hydrate',
#   'evolution',
#   'are',
#   'analyzed',
#   'by',
#   'applying',
#   'the',
#   'markov',
#   'state',
#   'model',
#   'msm',
#   'and',
#   'the',
#   'evolution',
#   'path',
#   'and',
#   'structure',
#   'conversion',
#   'are',
#   'revealed',
#   'for',
#   'the',
#   'first',
#   'time'],
#  ['the',
#   'results',
#   'show',
#   'that',
#   'nine',
#   'independent',
#   'metastable',
#   'states',
#   'can',
#   'be',
#   'identified',
#   'during',
#   'the',
#   'hydrate',
#   'formation',
#   'process'],
#  ['the',
#   'interconversion',
#   'between',
#   'the',
#   'states',
#   'is',
#   'at',
#   'timescales',
#   'of',
#   'nanoseconds',
#   'which',
#   'is',
#   'much',
#   'slower',
#   'than',
#   'that',
#   'of',
#   'convention',
#   'md',
#   'simulation'],
#  ['besides',
#   'according',
#   'to',
#   'the',
#   'transition',
#   'between',
#   'the',
#   'states',
#   'one',
#   'singletrack',
#   'path',
#   'along',
#   'the',
#   'metastable',
#   'states',
#   'can',
#   'lead',
#   'to',
#   'the',
#   'final',
#   'state',
#   'and',
#   'two',
#   'bidirectional',
#   'paths',
#   'are',
#   'caused',
#   'by',
#   'the',
#   'invasion',
#   'of',
#   'the',
#   'outer',
#   'methane',
#   'molecule',
#   'or',
#   'the',
#   'escape',
#   'of',
#   'the',
#   'existing',
#   'one'],
#  ['the',
#   'results',
#   'are',
#   'helpful',
#   'in',
#   'sampling',
#   'and',
#   'observing',
#   'the',
#   'hydrate',
#   'formation',
#   'process',
#   'under',
#   'laboratory',
#   'conditions',
#   'and',
#   'light',
#   'the',
#   'inspiration',
#   'for',
#   'controlling',
#   'the',
#   'hydrate',
#   'evolution',
#   'process',
#   'and',
#   'hydrate',
#   'recovery'],
#  ['introduction', 'hydrates', 'are', 'watercagesformed', 'crystals', 'sloan'],
#  ['in',
#   'these',
#   'cages',
#   'the',
#   'guest',
#   'molecules',
#   'such',
#   'as',
#   'methane',
#   'hydrogen',
#   'and',
#   'carbon',
#   'dioxide',
#   'are',
#   'trapped',
#   'by',
#   'the',
#   'cage',
#   'structure',
#   'but',
#   'not',
#   'by',
#   'hydrogen',
#   'bonds',
#   'liam',
#   'c',
#   'jacobson',
#   'hujo',
#   'molinero',
#   'veluswamy',
#   'et',
#   'al'],
#  ['in',
#   'recent',
#   'years',
#   'hydrates',
#   'have',
#   'drawn',
#   'great',
#   'attention',
#   'in',
#   'the',
#   'research',
#   'of',
#   'greenhouse',
#   'gas',
#   'fixation',
#   'and',
#   'future',
#   'energy',
#   'storage'],
#  ['for',
#   'example',
#   'the',
#   'ocean',
#   'floor',
#   'represents',
#   'a',
#   'perfect',
#   'place',
#   'for',
#   'the',
#   'nucleation',
#   'of',
#   'hydrate',
#   'to',
#   'fix',
#   'the',
#   'anthropogenic',
#   'released',
#   'into',
#   'the',
#   'atmosphere',
#   'herzog',
#   'caldeira',
#   'adams',
#   'radhakrishnan',
#   'trout',
#   'methane',
#   'hydrates',
#   'in',
#   'the',
#   'oceanic',
#   'sediments',
#   'and',
#   'permafrost',
#   'regions',
#   'stores',
#   'nature',
#   'gas',
#   'up',
#   'to',
#   'twice',
#   'that',
#   'of',
#   'all',
#   'fossil',
#   'fuel',
#   'deposits',
#   'englezos',
#   'e',
#   'd',
#   'sloan',
#   'jr',
#   'koh',
#   'hydrates',
#   'is',
#   'also',
#   'considered',
#   'as',
#   'the',
#   'potential',
#   'urtec',
#   'future',
#   'energystorage',
#   'medium',
#   'to',
#   'store',
#   'the',
#   'hydrogen',
#   'which',
#   'is',
#   'one',
#   'of',
#   'the',
#   'most',
#   'forefront',
#   'fuels',
#   'in',
#   'the',
#   'future',
#   'alshara',
#   'sher',
#   'iqbal',
#   'sajid',
#   'chen',
#   'mao',
#   'et',
#   'al'],
#  ['in',
#   'specifically',
#   'controlling',
#   'the',
#   'formation',
#   'of',
#   'clathrates',
#   'is',
#   'currently',
#   'one',
#   'of',
#   'the',
#   'most',
#   'important',
#   'thresholds',
#   'for',
#   'the',
#   'above',
#   'purposes'],
#  ['in',
#   'this',
#   'study',
#   'we',
#   'mainly',
#   'focus',
#   'on',
#   'understanding',
#   'the',
#   'formation',
#   'or',
#   'the',
#   'nucleation',
#   'process',
#   'of',
#   'the',
#   'methane',
#   'hydrate'],
#  ['the',
#   'results',
#   'are',
#   'prescriptive',
#   'for',
#   'promoting',
#   'hydrate',
#   'formationdecompose',
#   'veluswamy',
#   'kumar',
#   'kumar',
#   'linga',
#   'and',
#   'preventing',
#   'their',
#   'nucleation',
#   'in',
#   'some',
#   'transmission',
#   'pipelines',
#   'perrin',
#   'musa',
#   'steed',
#   'storr',
#   'taylor',
#   'monfort',
#   'rodger',
#   'and',
#   'provide',
#   'research',
#   'ideas',
#   'for',
#   'the',
#   'longlast',
#   'future',
#   'study'],
#  ['efforts',
#   'have',
#   'been',
#   'made',
#   'by',
#   'researchers',
#   'to',
#   'explore',
#   'the',
#   'nucleation',
#   'process',
#   'of',
#   'hydrate'],
#  ['as',
#   'early',
#   'as',
#   'the',
#   'crystal',
#   'diffraction',
#   'was',
#   'applied',
#   'to',
#   'explain',
#   'the',
#   'mechanism',
#   'of',
#   'the',
#   'hydrate',
#   'nucleation',
#   'and',
#   'it',
#   'was',
#   'concluded',
#   'that',
#   'during',
#   'the',
#   'nucleation',
#   'process',
#   'some',
#   'tiny',
#   'structures',
#   'would',
#   'absorb',
#   'energy',
#   'from',
#   'water',
#   'molecules',
#   'making',
#   'the',
#   'structure',
#   'tends',
#   'to',
#   'be',
#   'stable',
#   'then',
#   'these',
#   'stable',
#   'clusters',
#   'assemble',
#   'in',
#   'different',
#   'configurations',
#   'among',
#   'which',
#   'only',
#   'a',
#   'few',
#   'are',
#   'in',
#   'hydrate',
#   'structure',
#   'e',
#   'sloan',
#   'jr',
#   'fleyfel'],
#  ['this',
#   'mechanism',
#   'is',
#   'called',
#   'the',
#   'labile',
#   'cluster',
#   'hypothesis',
#   'christiansen',
#   'sloan',
#   'jr',
#   'radhakrishnan',
#   'trout',
#   'e',
#   'd',
#   'sloan',
#   'jr',
#   'koh'],
#  ['within',
#   'the',
#   'first',
#   'decade',
#   'of',
#   'the',
#   'century',
#   'by',
#   'conducting',
#   'molecular',
#   'dynamic',
#   'simulations',
#   'the',
#   'local',
#   'structure',
#   'hypothesis',
#   'was',
#   'proposed',
#   'to',
#   'interpret',
#   'the',
#   'mechanism',
#   'of',
#   'hydrate',
#   'nucleation',
#   'anderson',
#   'tester',
#   'borghi',
#   'trout'],
#  ['this',
#   'hypothesis',
#   'indicated',
#   'that',
#   'the',
#   'guest',
#   'molecule',
#   'first',
#   'invades',
#   'into',
#   'a',
#   'clathratelike',
#   'cell',
#   'and',
#   'shakes',
#   'the',
#   'structure',
#   'of',
#   'water',
#   'assemblies',
#   'around'],
#  ['next',
#   'the',
#   'hydrate',
#   'nucleation',
#   'may',
#   'happen',
#   'after',
#   'the',
#   'number',
#   'of',
#   'local',
#   'guest',
#   'molecules',
#   'reaches',
#   'the',
#   'critical',
#   'value',
#   'liu',
#   'in',
#   'the',
#   'late',
#   'of',
#   'this',
#   'decade',
#   'another',
#   'local',
#   'structure',
#   'hypothesis',
#   'was',
#   'present',
#   'matthew',
#   'r',
#   'walsh',
#   'koh',
#   'sloan',
#   'sum',
#   'wu',
#   'which',
#   'separates',
#   'the',
#   'nucleation',
#   'process',
#   'into',
#   'the',
#   'methane',
#   'adsorption',
#   'stage',
#   'fluctuating',
#   'formation',
#   'and',
#   'dissociation',
#   'of',
#   'small',
#   'hydrate',
#   'cages',
#   'and',
#   'appearing',
#   'of',
#   'the',
#   'larger',
#   'cages'],
#  ['except',
#   'for',
#   'the',
#   'hypothesis',
#   'mentioned',
#   'above',
#   'in',
#   'the',
#   'second',
#   'decade',
#   'of',
#   'the',
#   'century',
#   'a',
#   'blob',
#   'model',
#   'was',
#   'put',
#   'forward',
#   'by',
#   'conducting',
#   'molecular',
#   'dynamics',
#   'simulations',
#   'of',
#   'the',
#   'hydrate',
#   'system',
#   'liam',
#   'c',
#   'jacobson',
#   'hujo',
#   'molinero'],
#  ['this',
#   'model',
#   'treats',
#   'the',
#   'nucleation',
#   'process',
#   'into',
#   'two',
#   'steps',
#   'the',
#   'guest',
#   'molecules',
#   'assemble',
#   'as',
#   'blobs',
#   'in',
#   'which',
#   'clathrate',
#   'cages',
#   'form',
#   'and',
#   'are',
#   'turned',
#   'into',
#   'the',
#   'nucleus',
#   'then',
#   'these',
#   'nucleus',
#   'converts',
#   'into',
#   'crystalline',
#   'clathrate',
#   'liam',
#   'c',
#   'jacobson',
#   'et',
#   'al'],
#  ['recently',
#   'more',
#   'focus',
#   'has',
#   'been',
#   'on',
#   'the',
#   'clathrate',
#   'nucleation',
#   'path'],
#  ['by',
#   'restricting',
#   'supersaturated',
#   'mixture',
#   'in',
#   'molecular',
#   'dynamics',
#   'simulations',
#   'jiménezángeles',
#   'and',
#   'firoozabadi',
#   'discovered',
#   'that',
#   'the',
#   'hydrate',
#   'nucleation',
#   'starts',
#   'when',
#   'the',
#   'amorphous',
#   'cluster',
#   'forms'],
#  ['this',
#   'amorphous',
#   'cluster',
#   'is',
#   'the',
#   'starting',
#   'point',
#   'of',
#   'the',
#   'crystalline',
#   'domains',
#   'jiménezángeles',
#   'firoozabadi'],
#  ['although',
#   'it',
#   'has',
#   'been',
#   'shown',
#   'in',
#   'some',
#   'study',
#   'that',
#   'there',
#   'are',
#   'multiple',
#   'paths',
#   'for',
#   'hydrate',
#   'nucleation',
#   'matthew',
#   'r',
#   'walsh',
#   'et',
#   'al',
#   'zhang',
#   'walsh',
#   'guo',
#   'some',
#   'specific',
#   'nucleation',
#   'path',
#   'for',
#   'methane',
#   'clathrate',
#   'growth',
#   'has',
#   'been',
#   'recognized'],
#  ['li', 'et', 'al'],
#  ['employed',
#   'the',
#   'ternary',
#   'waterring',
#   'aggregation',
#   'as',
#   'the',
#   'tracer',
#   'element',
#   'to',
#   'characterize',
#   'the',
#   'hydrate',
#   'growing'],
#  ['it',
#   'was',
#   'found',
#   'that',
#   'the',
#   'methane',
#   'molecules',
#   'first',
#   'aggregate',
#   'and',
#   'run',
#   'into',
#   'each',
#   'other',
#   'causing',
#   'the',
#   'hydration',
#   'shell',
#   'between',
#   'them',
#   'to',
#   'be',
#   'compressed',
#   'after',
#   'that',
#   'these',
#   'hydration',
#   'shells',
#   'are',
#   'disassembled',
#   'followed',
#   'by',
#   'the',
#   'nucleation',
#   'of',
#   'the',
#   'hydrate',
#   'li',
#   'et',
#   'al'],
#  ['by',
#   'using',
#   'an',
#   'analytical',
#   'formula',
#   'the',
#   'timescale',
#   'of',
#   'the',
#   'whole',
#   'nucleation',
#   'process',
#   'was',
#   'regarded',
#   'to',
#   'be',
#   'in',
#   'the',
#   'range',
#   'from',
#   'to'],
#  ['most',
#   'of',
#   'the',
#   'studies',
#   'above',
#   'were',
#   'conducted',
#   'using',
#   'molecular',
#   'dynamic',
#   'simulation',
#   'levitt',
#   'hirshberg',
#   'sharon',
#   'daggett',
#   'mohr',
#   'wilhelm',
#   'battino',
#   'zgarbová',
#   'otyepka',
#   'šponer',
#   'hobza',
#   'jurečka'],
#  ['however',
#   'it',
#   'is',
#   'quite',
#   'easy',
#   'to',
#   'reach',
#   'hundreds',
#   'of',
#   'gigabytes',
#   'for',
#   'a',
#   'standard',
#   'nanosecond',
#   'long',
#   'md',
#   'simulation',
#   'in',
#   'the',
#   'hydrate',
#   'nucleation',
#   'process'],
#  ['moreover',
#   'since',
#   'it',
#   'has',
#   'millions',
#   'of',
#   'time',
#   'steps',
#   'each',
#   'has',
#   'dimensions'],
#  ['with',
#   'such',
#   'largescale',
#   'and',
#   'highdimensional',
#   'data',
#   'it',
#   'is',
#   'inevitable',
#   'to',
#   'draw',
#   'an',
#   'uncomprehensive',
#   'conclusion',
#   'if',
#   'data',
#   'analysis',
#   'is',
#   'done',
#   'in',
#   'a',
#   'subjective',
#   'approach',
#   'noé',
#   'wang',
#   'lamim',
#   'ribeiro',
#   'tiwary'],
#  ['the',
#   'length',
#   'of',
#   'timestep',
#   'range',
#   'of',
#   'md',
#   'simulations',
#   'for',
#   'hydrate',
#   'growth',
#   'is',
#   'in',
#   'femtoseconds',
#   'which',
#   'has',
#   'a',
#   'large',
#   'gap',
#   'with',
#   'the',
#   'time',
#   'precision',
#   'of',
#   'experiments'],
#  ['markov',
#   'state',
#   'model',
#   'is',
#   'a',
#   'stochastic',
#   'model',
#   'used',
#   'to',
#   'model',
#   'randomly',
#   'changing',
#   'systems',
#   'where',
#   'it',
#   'is',
#   'assumed',
#   'that',
#   'future',
#   'states',
#   'depend',
#   'only',
#   'on',
#   'the',
#   'current',
#   'state',
#   'not',
#   'on',
#   'the',
#   'events',
#   'that',
#   'occurred',
#   'before',
#   'betz',
#   'dror',
#   'matsunaga',
#   'sugita',
#   'pande',
#   'beauchamp',
#   'bowman',
#   'prinz',
#   'et',
#   'al',
#   'röblitz',
#   'weber'],
#  ['besides',
#   'it',
#   'is',
#   'a',
#   'kind',
#   'of',
#   'machine',
#   'learning',
#   'method',
#   'which',
#   'can',
#   'extract',
#   'complex',
#   'patterns',
#   'and',
#   'relationships',
#   'from',
#   'large',
#   'data',
#   'urtec',
#   'sets',
#   'noé',
#   'tkatchenko',
#   'müller',
#   'clementi',
#   'therefore',
#   'it',
#   'can',
#   'achieve',
#   'a',
#   'more',
#   'objective',
#   'result'],
#  ['in',
#   'this',
#   'study',
#   'the',
#   'process',
#   'of',
#   'hydrate',
#   'growth',
#   'is',
#   'first',
#   'modeled',
#   'by',
#   'using',
#   'molecular',
#   'dynamics',
#   'simulation'],
#  ['then',
#   'the',
#   'data',
#   'obtained',
#   'from',
#   'the',
#   'md',
#   'simulation',
#   'was',
#   'processed',
#   'using',
#   'the',
#   'markov',
#   'state',
#   'model'],
#  ['after',
#   'that',
#   'the',
#   'stages',
#   'of',
#   'the',
#   'nucleation',
#   'process',
#   'and',
#   'the',
#   'corresponding',
#   'structure',
#   'transition',
#   'and',
#   'the',
#   'timescale',
#   'are',
#   'identified',
#   'for',
#   'the',
#   'first',
#   'time'],
#  ['the',
#   'conclusion',
#   'may',
#   'guide',
#   'sampling',
#   'and',
#   'observing',
#   'the',
#   'hydrate',
#   'nucleation',
#   'process',
#   'under',
#   'laboratory',
#   'conditions',
#   'and',
#   'light',
#   'the',
#   'inspiration',
#   'for',
#   'the',
#   'catalyst',
#   'designing',
#   'and',
#   'further',
#   'molecule',
#   'simulation',
#   'to',
#   'find',
#   'additives',
#   'that',
#   'may',
#   'restrain',
#   'or',
#   'accelerate',
#   'the',
#   'nucleation',
#   'process'],
#  ['method',
#   'molecular',
#   'dynamics',
#   'simulation',
#   'in',
#   'this',
#   'paper',
#   'the',
#   'nucleation',
#   'process',
#   'of',
#   'natural',
#   'gas',
#   'hydrate',
#   'was',
#   'studied',
#   'by',
#   'molecular',
#   'dynamics',
#   'simulations'],
#  ['to',
#   'do',
#   'the',
#   'simulation',
#   'it',
#   'should',
#   'first',
#   'set',
#   'the',
#   'initial',
#   'configuration',
#   'of',
#   'the',
#   'system'],
#  ['a',
#   'relatively',
#   'high',
#   'proportion',
#   'of',
#   'methane',
#   'is',
#   'necessary',
#   'for',
#   'the',
#   'nucleation',
#   'of',
#   'the',
#   'methane',
#   'clathrate',
#   'kashchiev',
#   'firoozabadi',
#   'li',
#   'et',
#   'al',
#   'therefore',
#   'a',
#   'fullgrown',
#   'hydrate',
#   'configuration',
#   'is',
#   'set',
#   'as',
#   'the',
#   'initial',
#   'state',
#   'of',
#   'the',
#   'model'],
#  ['this',
#   'hydrate',
#   'cell',
#   'contains',
#   'a',
#   'total',
#   'of',
#   'water',
#   'molecules',
#   'and',
#   'methane',
#   'molecules',
#   'in',
#   'a',
#   'cubic',
#   'cell',
#   'with',
#   'a',
#   'side',
#   'length',
#   'of',
#   'å'],
#  ['in',
#   'the',
#   'cell',
#   'there',
#   'are',
#   'dodecahedron',
#   'cages',
#   'cages',
#   'liam',
#   'c',
#   'jacobson',
#   'et',
#   'al',
#   'and',
#   'tetrakaidecahedrons',
#   'cages',
#   'liam',
#   'c',
#   'jacobson',
#   'et',
#   'al',
#   'which',
#   'makes',
#   'all',
#   'the',
#   'methane',
#   'molecules',
#   'trapped',
#   'in',
#   'the',
#   'cages'],
#  ['in',
#   'the',
#   'model',
#   'one',
#   'water',
#   'molecule',
#   'is',
#   'represented',
#   'as',
#   'the',
#   'combination',
#   'of',
#   'one',
#   'oxygen',
#   'atom',
#   'and',
#   'two',
#   'hydrogen',
#   'atoms',
#   'so',
#   'that',
#   'the',
#   'hydrogenbonded',
#   'structures',
#   'between',
#   'the',
#   'water',
#   'molecules',
#   'can',
#   'be',
#   'modeled',
#   'while',
#   'the',
#   'methane',
#   'molecule',
#   'is',
#   'represented',
#   'as',
#   'a',
#   'singular',
#   'molecule'],
#  ['the',
#   'force',
#   'field',
#   'parameters',
#   'for',
#   'oxygen',
#   'atom',
#   'and',
#   'hydrogen',
#   'atoms',
#   'in',
#   'the',
#   'water',
#   'molecule',
#   'and',
#   'methane',
#   'molecule',
#   'can',
#   'be',
#   'found',
#   'in',
#   'refs'],
#  ['jorgensen', 'jorgensen', 'madura', 'swenson'],
#  ['to',
#   'reduce',
#   'the',
#   'computational',
#   'cost',
#   'and',
#   'be',
#   'able',
#   'to',
#   'track',
#   'the',
#   'structure',
#   'evolution',
#   'one',
#   'unit',
#   'cell',
#   'is',
#   'extracted',
#   'from',
#   'the',
#   'initial',
#   'configuration',
#   'for',
#   'the',
#   'following',
#   'calculation'],
#  ['the',
#   'unitcell',
#   'model',
#   'is',
#   'asymmetric',
#   'because',
#   'of',
#   'the',
#   'periodic',
#   'boundary',
#   'condition',
#   'in',
#   'each',
#   'direction',
#   'which',
#   'has',
#   'also',
#   'been',
#   'applied',
#   'in',
#   'ref'],
#  ['lenz', 'ojamäe'],
#  ['an',
#   'opensource',
#   'code',
#   'called',
#   'lammps',
#   'thompson',
#   'et',
#   'al',
#   'is',
#   'applied',
#   'to',
#   'conduct',
#   'the',
#   'molecular',
#   'dynamics',
#   'simulations',
#   'with',
#   'the',
#   'time',
#   'step',
#   'of',
#   'fs'],
#  ['the',
#   'optimized',
#   'potentials',
#   'jorgensen',
#   'for',
#   'and',
#   'the',
#   'model',
#   'abascal',
#   'sanz',
#   'garcía',
#   'fernández',
#   'vega',
#   'for',
#   'water',
#   'are',
#   'selected',
#   'to',
#   'calculate',
#   'the',
#   'interactions',
#   'in',
#   'the',
#   'model'],
#  ['the',
#   'shake',
#   'algorithm',
#   'is',
#   'applied',
#   'to',
#   'fix',
#   'both',
#   'the',
#   'angles',
#   'and',
#   'the',
#   'bond',
#   'lengths',
#   'of',
#   'water',
#   'molecules',
#   'ryckaert',
#   'ciccotti',
#   'berendsen'],
#  ['the',
#   'cutoff',
#   'distance',
#   'of',
#   'å',
#   'is',
#   'applied',
#   'to',
#   'determine',
#   'the',
#   'lennardjones',
#   'interactions',
#   'and',
#   'the',
#   'geometric',
#   'combining',
#   'law',
#   'is',
#   'applied',
#   'for',
#   'the',
#   'crossterms'],
#  ['the',
#   'system',
#   'is',
#   'set',
#   'in',
#   'a',
#   'constanttemperature',
#   'and',
#   'constantpressure',
#   'ensemble',
#   'with',
#   'which',
#   'the',
#   'berendsen',
#   'method',
#   'berendsen',
#   'postma',
#   'van',
#   'gunsteren',
#   'dinola',
#   'haak',
#   'and',
#   'the',
#   'nosehoover',
#   'method',
#   'martyna',
#   'klein',
#   'tuckerman',
#   'are',
#   'applied'],
#  ['before',
#   'the',
#   'simulation',
#   'of',
#   'the',
#   'nucleation',
#   'process',
#   'the',
#   'melting',
#   'and',
#   'preequilibrium',
#   'processes',
#   'at',
#   'for',
#   'a',
#   'period',
#   'of',
#   'ns',
#   'and',
#   'for',
#   'ns',
#   'respectively',
#   'are',
#   'conducted',
#   'to',
#   'reach',
#   'the',
#   'starting',
#   'point',
#   'of',
#   'the',
#   'nucleation',
#   'process',
#   'calculation'],
#  ['then',
#   'the',
#   'simulation',
#   'for',
#   'the',
#   'nucleation',
#   'process',
#   'is',
#   'continued',
#   'for',
#   'a',
#   'total',
#   'time',
#   'of',
#   'ns',
#   'with',
#   'the',
#   'temperature',
#   'and',
#   'pressure',
#   'and',
#   'being',
#   'fixed',
#   'at',
#   'and'],
#  ['markov',
#   'state',
#   'model',
#   'construction',
#   'markov',
#   'state',
#   'model',
#   'is',
#   'a',
#   'stochastic',
#   'model',
#   'used',
#   'to',
#   'model',
#   'randomly',
#   'changing',
#   'systems',
#   'where',
#   'it',
#   'is',
#   'assumed',
#   'that',
#   'future',
#   'states',
#   'depend',
#   'only',
#   'on',
#   'the',
#   'current',
#   'state',
#   'not',
#   'on',
#   'the',
#   'events',
#   'that',
#   'occurred',
#   'before',
#   'pande',
#   'et',
#   'al'],
#  ['this', 'property', 'is', 'called', 'markov', 'property', 'or', 'markovian'],
#  ['here',
#   'we',
#   'summarize',
#   'a',
#   'detailed',
#   'procedure',
#   'of',
#   'msm',
#   'construction'],
#  ['the', 'first', 'stage', 'is', 'data', 'preparation'],
#  ['in',
#   'this',
#   'stage',
#   'we',
#   'should',
#   'run',
#   'a',
#   'bunch',
#   'of',
#   'small',
#   'trajectories',
#   'of',
#   'md',
#   'simulations',
#   'to',
#   'get',
#   'the',
#   'atom',
#   'cartesian',
#   'coordinates',
#   'as',
#   'the',
#   'function',
#   'of',
#   'simulation',
#   'time'],
#  ['next',
#   'we',
#   'will',
#   'define',
#   'the',
#   'features',
#   'eg',
#   'distances',
#   'between',
#   'atoms',
#   'dihedral',
#   'angles',
#   'or',
#   'molecular',
#   'contacts',
#   'to',
#   'characterize',
#   'the',
#   'molecular',
#   'structures'],
#  ['these',
#   'features',
#   'are',
#   'calculated',
#   'from',
#   'each',
#   'timeframe',
#   'thus',
#   'transforming',
#   'the',
#   'cartesian',
#   'coordinates',
#   'into',
#   'feature',
#   'vectors'],
#  ['then',
#   'a',
#   'urtec',
#   'linear',
#   'transformation',
#   'is',
#   'applied',
#   'to',
#   'reduce',
#   'the',
#   'feature',
#   'dimensions',
#   'such',
#   'as',
#   'using',
#   'timelagged',
#   'independent',
#   'component',
#   'analysis',
#   'tica'],
#  ['the',
#   'function',
#   'of',
#   'tica',
#   'is',
#   'quite',
#   'similar',
#   'to',
#   'principal',
#   'component',
#   'analysis',
#   'pca'],
#  ['the',
#   'major',
#   'difference',
#   'between',
#   'them',
#   'is',
#   'that',
#   'the',
#   'calculated',
#   'components',
#   'eigenvectors',
#   'from',
#   'pca',
#   'is',
#   'based',
#   'on',
#   'covariance',
#   'matrix',
#   'which',
#   'can',
#   'capture',
#   'the',
#   'feature',
#   'variance',
#   'however',
#   'the',
#   'calculated',
#   'components',
#   'from',
#   'tica',
#   'are',
#   'based',
#   'on',
#   'autocorrelation',
#   'matrix',
#   'which',
#   'captures',
#   'the',
#   'slow',
#   'change',
#   'direction',
#   'of',
#   'features'],
#  ['since',
#   'the',
#   'purpose',
#   'of',
#   'msm',
#   'is',
#   'to',
#   'extend',
#   'the',
#   'timescale',
#   'of',
#   'the',
#   'md',
#   'simulation',
#   'we',
#   'want',
#   'to',
#   'our',
#   'components',
#   'maximizing',
#   'the',
#   'slow',
#   'change',
#   'direction',
#   'as',
#   'much',
#   'as',
#   'they',
#   'can'],
#  ['that',
#   'is',
#   'we',
#   'will',
#   'choose',
#   'the',
#   'components',
#   'corresponding',
#   'to',
#   'the',
#   'largest',
#   'autocorrelations',
#   'or',
#   'eigenvalues'],
#  ['next',
#   'we',
#   'will',
#   'use',
#   'tica',
#   'components',
#   'corresponding',
#   'to',
#   'the',
#   'first',
#   'two',
#   'or',
#   'three',
#   'largest',
#   'autocorrelations',
#   'to',
#   'plot',
#   'the',
#   'free',
#   'energy',
#   'map',
#   'or',
#   'surface'],
#  ['then',
#   'we',
#   'will',
#   'use',
#   'this',
#   'mapping',
#   'data',
#   'to',
#   'define',
#   'microstates',
#   'using',
#   'clustering',
#   'methods',
#   'such',
#   'as',
#   'kmeans'],
#  ['at',
#   'this',
#   'time',
#   'we',
#   'can',
#   'count',
#   'the',
#   'state',
#   'transitions',
#   'among',
#   'each',
#   'microstate',
#   'to',
#   'get',
#   'the',
#   'original',
#   'transition',
#   'counts',
#   'matrix'],
#  ['once',
#   'we',
#   'get',
#   'the',
#   'original',
#   'transition',
#   'count',
#   'matrix',
#   'it',
#   'is',
#   'still',
#   'difficult',
#   'for',
#   'us',
#   'to',
#   'apply',
#   'it',
#   'to',
#   'study',
#   'the',
#   'change',
#   'of',
#   'molecular',
#   'structure',
#   'due',
#   'to',
#   'its',
#   'high',
#   'dimension'],
#  ['so',
#   'we',
#   'need',
#   'to',
#   'cluster',
#   'the',
#   'microstates',
#   'to',
#   'metastates',
#   'by',
#   'using',
#   'the',
#   'perroncluster',
#   'cluster',
#   'analysis',
#   'pcca'],
#  ['this', 'process', 'is', 'called', 'coarse', 'graining'],
#  ['once',
#   'we',
#   'have',
#   'the',
#   'metastates',
#   'then',
#   'we',
#   'can',
#   'count',
#   'the',
#   'state',
#   'transitions',
#   'among',
#   'each',
#   'metastate',
#   'to',
#   'obtain',
#   'a',
#   'smaller',
#   'transition',
#   'count',
#   'matrix'],
#  ['finally',
#   'we',
#   'can',
#   'build',
#   'the',
#   'msm',
#   'network',
#   'according',
#   'to',
#   'the',
#   'transition',
#   'probability',
#   'matrix'],
#  ['results',
#   'and',
#   'discussion',
#   'free',
#   'energy',
#   'and',
#   'microstate',
#   'distribution',
#   'free',
#   'energy',
#   'map',
#   'shows',
#   'the',
#   'free',
#   'energy',
#   'map',
#   'with',
#   'the',
#   'coordinates',
#   'by',
#   'using',
#   'timelagged',
#   'independent',
#   'component',
#   'analysis'],
#  ['it',
#   'can',
#   'be',
#   'seen',
#   'that',
#   'there',
#   'are',
#   'welldistinguished',
#   'regions',
#   'in',
#   'the',
#   'free',
#   'energy',
#   'map'],
#  ['although',
#   'it',
#   'is',
#   'difficult',
#   'to',
#   'define',
#   'the',
#   'nucleation',
#   'stage',
#   'of',
#   'hydrate',
#   'several',
#   'local',
#   'energy',
#   'minimums',
#   'exist',
#   'in',
#   'the',
#   'entire',
#   'evolution',
#   'period'],
#  ['each',
#   'local',
#   'energy',
#   'minimum',
#   'represents',
#   'a',
#   'possible',
#   'stable',
#   'or',
#   'metastable',
#   'structure',
#   'of',
#   'hydrate',
#   'during',
#   'the',
#   'nucleation',
#   'process'],
#  ['it',
#   'can',
#   'also',
#   'be',
#   'seen',
#   'in',
#   'that',
#   'the',
#   'minimum',
#   'value',
#   'in',
#   'the',
#   'free',
#   'energy',
#   'map',
#   'is',
#   'near',
#   'the',
#   'coordinate',
#   'of'],
#  ['besides',
#   'the',
#   'system',
#   'structure',
#   'extracted',
#   'at',
#   'this',
#   'coordinate',
#   'is',
#   'the',
#   'fullgrown',
#   'hydrate',
#   'clathrate'],
#  ['therefore',
#   'the',
#   'hydrate',
#   'is',
#   'the',
#   'most',
#   'stable',
#   'state',
#   'of',
#   'the',
#   'system'],
#  ['urtec',
#   'distribution',
#   'of',
#   'microstates',
#   'by',
#   'using',
#   'the',
#   'kmeans',
#   'cluster',
#   'method',
#   'microstates',
#   'can',
#   'be',
#   'identified',
#   'as',
#   'shown',
#   'in'],
#  ['it',
#   'should',
#   'be',
#   'noted',
#   'that',
#   'a',
#   'sufficient',
#   'number',
#   'of',
#   'microstates',
#   'is',
#   'necessary',
#   'for',
#   'the',
#   'determination',
#   'of',
#   'the',
#   'coarsegraining',
#   'and',
#   'evolution',
#   'stage'],
#  ['in', 'this', 'study', 'microstates', 'are', 'clustered'],
#  ['by',
#   'comparing',
#   'and',
#   'it',
#   'can',
#   'be',
#   'noted',
#   'that',
#   'the',
#   'microstates',
#   'aggregates',
#   'at',
#   'the',
#   'local',
#   'energy',
#   'minimum',
#   'which',
#   'also',
#   'proves',
#   'that',
#   'there',
#   'are',
#   'several',
#   'metastable',
#   'states',
#   'during',
#   'the',
#   'whole',
#   'evolution',
#   'period'],
#  ['time',
#   'scale',
#   'of',
#   'the',
#   'hydrate',
#   'nucleation',
#   'process',
#   'implied',
#   'timescale',
#   'as',
#   'the',
#   'function',
#   'of',
#   'the',
#   'lag',
#   'time',
#   'shows',
#   'the',
#   'implied',
#   'timescale',
#   'as',
#   'the',
#   'function',
#   'of',
#   'the',
#   'lag',
#   'time'],
#  ['if',
#   'the',
#   'lag',
#   'time',
#   'is',
#   'correct',
#   'to',
#   'give',
#   'markov',
#   'property',
#   'the',
#   'implied',
#   'timescale',
#   'as',
#   'the',
#   'function',
#   'of',
#   'the',
#   'lag',
#   'time',
#   'should',
#   'be',
#   'level',
#   'and',
#   'the',
#   'timescale',
#   'urtec',
#   'of',
#   'the',
#   'process',
#   'can',
#   'be',
#   'determined',
#   'matsunaga',
#   'sugita'],
#  ['it',
#   'can',
#   'be',
#   'seen',
#   'in',
#   'that',
#   'the',
#   'lines',
#   'become',
#   'level',
#   'when',
#   'the',
#   'implied',
#   'timescale',
#   'is',
#   'larger',
#   'than'],
#  ['however',
#   'color',
#   'lines',
#   'in',
#   'enter',
#   'the',
#   'gray',
#   'region',
#   'where',
#   'the',
#   'lag',
#   'time',
#   'is',
#   'larger',
#   'than'],
#  ['in',
#   'this',
#   'region',
#   'the',
#   'estimation',
#   'becomes',
#   'unreliable',
#   'because',
#   'lag',
#   'time',
#   'is',
#   'larger',
#   'than',
#   'the',
#   'timescale',
#   'which',
#   'makes',
#   'the',
#   'process',
#   'decay'],
#  ['therefore',
#   'it',
#   'is',
#   'believed',
#   'that',
#   'the',
#   'timescale',
#   'of',
#   'the',
#   'hydrate',
#   'nucleation',
#   'process',
#   'is'],
#  ['this',
#   'means',
#   'that',
#   'only',
#   'the',
#   'observed',
#   'equipment',
#   'having',
#   'a',
#   'time',
#   'resolution',
#   'higher',
#   'than',
#   'can',
#   'identify',
#   'the',
#   'continuous',
#   'change',
#   'of',
#   'hydrate',
#   'structure'],
#  ['moreover',
#   'for',
#   'the',
#   'division',
#   'of',
#   'further',
#   'states',
#   'a',
#   'suitable',
#   'lag',
#   'time',
#   'can',
#   'be',
#   'determined',
#   'from',
#   'which',
#   'is',
#   'in',
#   'this',
#   'study'],
#  ['therefore',
#   'by',
#   'extending',
#   'the',
#   'timescale',
#   'of',
#   'femtoseconds',
#   'in',
#   'conventional',
#   'molecular',
#   'dynamics',
#   'simulation',
#   'to',
#   'the',
#   'timescale',
#   'of',
#   'nanoseconds',
#   'through',
#   'msm',
#   'analysis',
#   'guidance',
#   'for',
#   'sampling',
#   'and',
#   'observation',
#   'period',
#   'may',
#   'be',
#   'provided',
#   'in',
#   'looking',
#   'into',
#   'the',
#   'hydrate',
#   'nucleation',
#   'process',
#   'under',
#   'the',
#   'equipment',
#   'such',
#   'as',
#   'a',
#   'twophoton',
#   'microscope'],
#  ['the',
#   'ten',
#   'states',
#   'identified',
#   'by',
#   'the',
#   'markov',
#   'state',
#   'model'],
#  ['according',
#   'to',
#   'the',
#   'analysis',
#   'and',
#   'the',
#   'validation',
#   'the',
#   'state',
#   's',
#   'number',
#   'of',
#   'ten',
#   'and',
#   'lag',
#   'time',
#   'of',
#   'are',
#   'selected',
#   'as',
#   'the',
#   'inputs',
#   'to',
#   'the',
#   'msm',
#   'model'],
#  ['then', 'the', 'states', 'can', 'be', 'identified', 'as', 'shown', 'in'],
#  ['it',
#   'can',
#   'be',
#   'seen',
#   'in',
#   'that',
#   'there',
#   'are',
#   'clear',
#   'interfaces',
#   'between',
#   'each',
#   'state'],
#  ['by',
#   'comparing',
#   'and',
#   'except',
#   'state',
#   'which',
#   'has',
#   'the',
#   'highest',
#   'free',
#   'energy',
#   'and',
#   'is',
#   'the',
#   'initial',
#   'state',
#   'of',
#   'the',
#   'system',
#   'each',
#   'state',
#   'has',
#   'a',
#   'local',
#   'energy',
#   'minimum',
#   'indicating',
#   'a',
#   'metastable',
#   'state'],
#  ['therefore',
#   'during',
#   'the',
#   'entire',
#   'lifetime',
#   'of',
#   'the',
#   'nucleation',
#   'process',
#   'there',
#   'are',
#   'nine',
#   'metastable',
#   'states',
#   'and',
#   'each',
#   'has',
#   'a',
#   'specific',
#   'nucleation',
#   'structure'],
#  ['states',
#   'and',
#   'structures',
#   'transition',
#   'of',
#   'the',
#   'nucleation',
#   'process',
#   'urtec',
#   'transition',
#   'network',
#   'between',
#   'states',
#   'with',
#   'lifetimes',
#   'on',
#   'the',
#   'order',
#   'of',
#   'ns'],
#  ['based',
#   'on',
#   'the',
#   'initial',
#   'state',
#   'and',
#   'nine',
#   'metastable',
#   'states',
#   'obtained',
#   'in',
#   'the',
#   'above',
#   'section',
#   'and',
#   'the',
#   'related',
#   'transition',
#   'matrix',
#   'the',
#   'transition',
#   'between',
#   'the',
#   'states',
#   'can',
#   'be',
#   'determined'],
#  ['shows',
#   'the',
#   'transition',
#   'network',
#   'between',
#   'states',
#   'within',
#   'the',
#   'lifetime'],
#  ['in',
#   'this',
#   'figure',
#   'the',
#   'area',
#   'of',
#   'the',
#   'circle',
#   'is',
#   'proportional',
#   'to',
#   'the',
#   'stationary',
#   'distribution',
#   'of',
#   'the',
#   'corresponding',
#   'state'],
#  ['the',
#   'direction',
#   'and',
#   'thickness',
#   'of',
#   'the',
#   'arrows',
#   'represent',
#   'the',
#   'transition',
#   'path',
#   'and',
#   'the',
#   'magnitude',
#   'of',
#   'transition',
#   'probability',
#   'between',
#   'different',
#   'states',
#   'respectively'],
#  ['initially',
#   'it',
#   'can',
#   'be',
#   'observed',
#   'that',
#   'the',
#   'molecular',
#   'configuration',
#   'of',
#   'state',
#   'is',
#   'at',
#   'the',
#   'preequilibrated',
#   'condition',
#   'while',
#   'state',
#   'is',
#   'at',
#   'the',
#   'equilibrium',
#   'condition',
#   'in',
#   'which',
#   'the',
#   'methane',
#   'clathrate',
#   'has',
#   'fully',
#   'grown'],
#  ['then',
#   'it',
#   'can',
#   'be',
#   'found',
#   'in',
#   'that',
#   'although',
#   'there',
#   'are',
#   'several',
#   'metastable',
#   'states',
#   'between',
#   'the',
#   'initial',
#   'state',
#   'and',
#   'state',
#   'only',
#   'state',
#   'has',
#   'a',
#   'direct',
#   'connection',
#   'with',
#   'the',
#   'full',
#   'grow',
#   'hydrate'],
#  ['this',
#   'probably',
#   'means',
#   'that',
#   'a',
#   'specific',
#   'molecular',
#   'structure',
#   'in',
#   'state',
#   'plays',
#   'an',
#   'important',
#   'role',
#   'in',
#   'the',
#   'nucleation',
#   'process'],
#  ['besides',
#   'just',
#   'as',
#   'the',
#   'theory',
#   'of',
#   'msm',
#   'indicates',
#   'the',
#   'structure',
#   'in',
#   'each',
#   'stage',
#   'is',
#   'directly',
#   'connected',
#   'with',
#   'the',
#   'next',
#   'therefore',
#   'for',
#   'a',
#   'full',
#   'understanding',
#   'of',
#   'the',
#   'hydrate',
#   'nucleation',
#   'process',
#   'the',
#   'molecular',
#   'structures',
#   'along',
#   'the',
#   'state',
#   'transition',
#   'path',
#   'should',
#   'be',
#   'highlighted'],
#  ['representative',
#   'structures',
#   'of',
#   'kinetic',
#   'clusters',
#   'shows',
#   'the',
#   'representative',
#   'structures',
#   'for',
#   'each',
#   'metastable',
#   'state',
#   'and',
#   'they',
#   'are',
#   'arranged',
#   'in',
#   'the',
#   'layout',
#   'as',
#   'that',
#   'in'],
#  ['as', 'mentioned', 'in', 'ref'],
#  ['li',
#   'et',
#   'al',
#   'the',
#   'nucleation',
#   'happens',
#   'around',
#   'the',
#   'interactive',
#   'and',
#   'adjacent',
#   'methane',
#   'molecules',
#   'therefore',
#   'the',
#   'methane',
#   'molecules',
#   'with',
#   'a',
#   'distance',
#   'less',
#   'than',
#   'and',
#   'the',
#   'water',
#   'molecule',
#   'around',
#   'them',
#   'are',
#   'considered'],
#  ['besides',
#   'it',
#   'should',
#   'be',
#   'noted',
#   'that',
#   'to',
#   'have',
#   'a',
#   'complete',
#   'morphological',
#   'structure',
#   'the',
#   'study',
#   'object',
#   'is',
#   'obtained',
#   'from',
#   'the',
#   'repeatedly',
#   'arranged',
#   'unit',
#   'cell',
#   'due',
#   'to',
#   'the',
#   'periodic',
#   'boundary',
#   'condition'],
#  ['however',
#   'it',
#   'is',
#   'difficult',
#   'to',
#   'summarize',
#   'the',
#   'characteristics',
#   'of',
#   'each',
#   'structure'],
#  ['only',
#   'the',
#   'fully',
#   'grown',
#   'hydrate',
#   'can',
#   'be',
#   'recognized',
#   'in',
#   'state',
#   'which',
#   'is',
#   'consistent',
#   'with',
#   'the',
#   'lowest',
#   'energy',
#   'position',
#   'in'],
#  ['urtec',
#   'reduced',
#   'representative',
#   'structures',
#   'of',
#   'kinetic',
#   'clusters',
#   'the',
#   'vibration',
#   'and',
#   'the',
#   'collision',
#   'between',
#   'the',
#   'methane',
#   'molecule',
#   'lead',
#   'to',
#   'the',
#   'compressionshedding',
#   'of',
#   'the',
#   'hydration',
#   'layer',
#   'li',
#   'et',
#   'al'],
#  ['accordingly',
#   'to',
#   'find',
#   'out',
#   'the',
#   'structure',
#   'change',
#   'during',
#   'the',
#   'nucleation',
#   'process',
#   'the',
#   'reduced',
#   'representative',
#   'structures',
#   'of',
#   'each',
#   'metastable',
#   'state',
#   'are',
#   'presented',
#   'in'],
#  ['the',
#   'reduced',
#   'representative',
#   'structures',
#   'only',
#   'consider',
#   'the',
#   'adjacent',
#   'methane',
#   'molecules',
#   'and',
#   'the',
#   'water',
#   'rings',
#   'between',
#   'two',
#   'methane',
#   'molecules'],
#  ['in',
#   'this',
#   'way',
#   'the',
#   'path',
#   'of',
#   'structural',
#   'change',
#   'can',
#   'be',
#   'identified',
#   'clearly'],
#  ['it',
#   'can',
#   'be',
#   'seen',
#   'in',
#   'that',
#   'the',
#   'metastable',
#   'state',
#   'appears',
#   'after',
#   'the',
#   'initial',
#   'state'],
#  ['in',
#   'the',
#   'state',
#   'two',
#   'or',
#   'three',
#   'methane',
#   'molecules',
#   'interact',
#   'with',
#   'each',
#   'other',
#   'and',
#   'the',
#   'water',
#   'rings',
#   'between',
#   'them',
#   'only',
#   'share',
#   'one',
#   'point',
#   'or',
#   'one',
#   'edge'],
#  ['state',
#   'comes',
#   'after',
#   'the',
#   'state',
#   'and',
#   'it',
#   's',
#   'a',
#   'oneway',
#   'path'],
#  ['in',
#   'state',
#   'there',
#   'are',
#   'four',
#   'interrelated',
#   'methane',
#   'molecules',
#   'and',
#   'interaction',
#   'happens',
#   'between',
#   'every',
#   'two',
#   'molecules',
#   'except',
#   'for',
#   'the',
#   'tail',
#   'one',
#   'and',
#   'head',
#   'one'],
#  ['there', 'are', 'three', 'paths', 'after', 'state'],
#  ['one',
#   'is',
#   'the',
#   'oneway',
#   'path',
#   'to',
#   'state',
#   'the',
#   'other',
#   'two',
#   'are',
#   'the',
#   'twoway',
#   'paths',
#   'connecting',
#   'with',
#   'state',
#   'and',
#   'state'],
#  ['as',
#   'the',
#   'analysis',
#   'in',
#   'the',
#   'above',
#   'section',
#   'the',
#   'hydrate',
#   'has',
#   'fully',
#   'grown',
#   'in',
#   'state'],
#  ['in',
#   'this',
#   'state',
#   'the',
#   'four',
#   'methane',
#   'molecules',
#   'in',
#   'state',
#   'connect',
#   'with',
#   'each',
#   'other',
#   'and',
#   'form',
#   'a',
#   'tetrahedron'],
#  ['there',
#   'is',
#   'a',
#   'fivepointed',
#   'water',
#   'ring',
#   'around',
#   'each',
#   'edge',
#   'of',
#   'the',
#   'tetrahedron'],
#  ['state',
#   'is',
#   'reached',
#   'by',
#   'one',
#   'methane',
#   'molecule',
#   'invading',
#   'state'],
#  ['the',
#   'methane',
#   'molecules',
#   'in',
#   'state',
#   'also',
#   'form',
#   'a',
#   'tetrahedron',
#   'similar',
#   'to',
#   'that',
#   'in',
#   'state',
#   'but',
#   'with',
#   'methane',
#   'in',
#   'its',
#   'center'],
#  ['then', 'state', 'transforms', 'to', 'state', 'state', 'and', 'state'],
#  ['in',
#   'this',
#   'path',
#   'two',
#   'methane',
#   'molecules',
#   'at',
#   'the',
#   'point',
#   'of',
#   'tetrahedron',
#   'will',
#   'escape',
#   'from',
#   'the',
#   'structure',
#   'one',
#   'after',
#   'another'],
#  ['in',
#   'the',
#   'path',
#   'from',
#   'state',
#   'to',
#   'state',
#   'and',
#   'state',
#   'one',
#   'water',
#   'ring',
#   'is',
#   'distorted',
#   'and',
#   'one',
#   'methane',
#   'molecule',
#   'escapes',
#   'during',
#   'the',
#   'process'],
#  ['according',
#   'to',
#   'the',
#   'analysis',
#   'of',
#   'the',
#   'path',
#   'and',
#   'structure',
#   'above',
#   'it',
#   'can',
#   'be',
#   'seen',
#   'that',
#   'although',
#   'there',
#   'are',
#   'as',
#   'many',
#   'as',
#   'ten',
#   'states',
#   'only',
#   'one',
#   'oneway',
#   'path',
#   'can',
#   'lead',
#   'to',
#   'the',
#   'final',
#   'state'],
#  ['the',
#   'other',
#   'twoway',
#   'paths',
#   'are',
#   'caused',
#   'by',
#   'the',
#   'change',
#   'of',
#   'the',
#   'water',
#   'rings',
#   'structure',
#   'due',
#   'to',
#   'the',
#   'invasion',
#   'of',
#   'the',
#   'outer',
#   'methane',
#   'molecule',
#   'or',
#   'the',
#   'escape',
#   'of',
#   'the',
#   'existing',
#   'one'],
#  ['these',
#   'twoway',
#   'paths',
#   'could',
#   'substantially',
#   'slow',
#   'down',
#   'the',
#   'nucleation',
#   'process'],
#  ['therefore',
#   'based',
#   'on',
#   'the',
#   'recognized',
#   'structures',
#   'along',
#   'the',
#   'twoway',
#   'path',
#   'catalyst',
#   'designing',
#   'and',
#   'further',
#   'molecule',
#   'simulation',
#   'could',
#   'be',
#   'done',
#   'to',
#   'find',
#   'additives',
#   'that',
#   'may',
#   'restrain',
#   'the',
#   'twoway',
#   'path'],
#  ['conclusions',
#   'urtec',
#   'several',
#   'local',
#   'energy',
#   'minimums',
#   'exist',
#   'at',
#   'the',
#   'freeenergy',
#   'map',
#   'for',
#   'the',
#   'entire',
#   'lifetime',
#   'of',
#   'the',
#   'nucleation',
#   'process',
#   'and',
#   'the',
#   'free',
#   'energy',
#   'of',
#   'the',
#   'fullgrown',
#   'hydrate',
#   'clathrate',
#   'is',
#   'at',
#   'the',
#   'lowest',
#   'point',
#   'of',
#   'the',
#   'map'],
#  ['this',
#   'means',
#   'that',
#   'the',
#   'hydrate',
#   'nucleation',
#   'process',
#   'follows',
#   'a',
#   'specific',
#   'path',
#   'passing',
#   'by',
#   'these',
#   'energy',
#   'minimums'],
#  ['by',
#   'applying',
#   'the',
#   'msm',
#   'analysis',
#   'the',
#   'timescale',
#   'of',
#   'femtoseconds',
#   'in',
#   'conventional',
#   'molecular',
#   'dynamics',
#   'simulation',
#   'is',
#   'extended',
#   'to',
#   'the',
#   'timescale',
#   'of',
#   'nanoseconds'],
#  ['with',
#   'this',
#   'long',
#   'enough',
#   'timescale',
#   'guidance',
#   'for',
#   'sampling',
#   'and',
#   'observation',
#   'period',
#   'may',
#   'be',
#   'provided',
#   'in',
#   'looking',
#   'into',
#   'the',
#   'hydrate',
#   'nucleation',
#   'process',
#   'under',
#   'experiment',
#   'conditions'],
#  ['ten',
#   'states',
#   'can',
#   'be',
#   'identified',
#   'during',
#   'the',
#   'entire',
#   'lifetime',
#   'of',
#   'the',
#   'hydrate',
#   'nucleation',
#   'process',
#   'between',
#   'which',
#   'there',
#   'are',
#   'clear',
#   'interfaces'],
#  ['this', 'has', 'been', 'validated', 'by', 'applying', 'the', 'ck', 'test'],
#  ['except',
#   'for',
#   'the',
#   'initial',
#   'state',
#   'of',
#   'the',
#   'system',
#   'each',
#   'state',
#   'has',
#   'a',
#   'local',
#   'energy',
#   'minimum',
#   'indicating',
#   'a',
#   'metastable',
#   'state'],
#  ['according',
#   'to',
#   'the',
#   'transition',
#   'network',
#   'between',
#   'states',
#   'and',
#   'the',
#   'corresponding',
#   'structures',
#   'only',
#   'one',
#   'oneway',
#   'path',
#   'can',
#   'lead',
#   'to',
#   'the',
#   'final',
#   'state'],
#  ['the',
#   'other',
#   'twoway',
#   'paths',
#   'are',
#   'caused',
#   'by',
#   'the',
#   'change',
#   'of',
#   'the',
#   'water',
#   'rings',
#   'structure',
#   'due',
#   'to',
#   'the',
#   'invasion',
#   'of',
#   'the',
#   'outer',
#   'methane',
#   'molecule',
#   'or',
#   'the',
#   'escape',
#   'of',
#   'the',
#   'existing',
#   'one'],
#  ['these',
#   'twoway',
#   'paths',
#   'could',
#   'substantially',
#   'slow',
#   'down',
#   'the',
#   'nucleation',
#   'process'],
#  ['because',
#   'there',
#   'is',
#   'only',
#   'one',
#   'way',
#   'to',
#   'the',
#   'final',
#   'state',
#   'we',
#   'can',
#   'do',
#   'catalyst',
#   'designing',
#   'or',
#   'find',
#   'some',
#   'additives',
#   'to',
#   'prevent',
#   'the',
#   'formation',
#   'or',
#   'decomposition',
#   'of',
#   'gas',
#   'hydrate',
#   'during',
#   'oilgas',
#   'surface',
#   'transport',
#   'or',
#   'gas',
#   'hydrate',
#   'exploration'],
#  ['more',
#   'importantly',
#   'this',
#   'finding',
#   'reveals',
#   'the',
#   'controlling',
#   'physics',
#   'inside',
#   'the',
#   'gas',
#   'hydrate',
#   'and',
#   'can',
#   'extend',
#   'to',
#   'subsurface',
#   'carbon',
#   'dioxide',
#   'sequestration'],
#  ['acknowledgments',
#   'we',
#   'acknowledge',
#   'that',
#   'this',
#   'study',
#   'was',
#   'partially',
#   'supported',
#   'by',
#   'the',
#   'national',
#   'natural',
#   'science',
#   'foundation',
#   'of',
#   'china',
#   'no'],
#  ['and',
#   'the',
#   'fundamental',
#   'research',
#   'funds',
#   'for',
#   'the',
#   'central',
#   'universities'],
#  ['we',
#   'also',
#   'want',
#   'to',
#   'express',
#   'our',
#   'great',
#   'attitude',
#   'to',
#   'tingen',
#   'fan',
#   'zhiwang',
#   'yuan',
#   'and',
#   'botao',
#   'kang',
#   'for',
#   'their',
#   'help',
#   'and',
#   'advice'],
#  ['references',
#   'abascal',
#   'j',
#   'sanz',
#   'e',
#   'garcía',
#   'fernández',
#   'r',
#   'vega',
#   'c'],
#  ['a',
#   'potential',
#   'model',
#   'for',
#   'the',
#   'study',
#   'of',
#   'ices',
#   'and',
#   'amorphous',
#   'water'],
#  ['the', 'journal', 'of', 'chemical', 'physics'],
#  ['alshara',
#   'n',
#   'k',
#   'sher',
#   'f',
#   'iqbal',
#   's',
#   'z',
#   'sajid',
#   'z',
#   'chen',
#   'g',
#   'z'],
#  [],
#  ['electrochemical',
#   'study',
#   'of',
#   'different',
#   'membrane',
#   'materials',
#   'for',
#   'the',
#   'fabrication',
#   'of',
#   'stable',
#   'reproducible',
#   'and',
#   'reusable',
#   'reference',
#   'electrode'],
#  ['journal', 'of', 'energy', 'chemistry'],
#  ['anderson',
#   'b',
#   'j',
#   'tester',
#   'j',
#   'w',
#   'borghi',
#   'g',
#   'p',
#   'trout',
#   'b',
#   'l'],
#  ['properties',
#   'of',
#   'inhibitors',
#   'of',
#   'methane',
#   'hydrate',
#   'formation',
#   'via',
#   'molecular',
#   'dynamics',
#   'simulations'],
#  ['journal',
#   'of',
#   'the',
#   'american',
#   'chemical',
#   'society',
#   'doi',
#   'berendsen',
#   'h',
#   'j',
#   'postma',
#   'j',
#   'v',
#   'van',
#   'gunsteren',
#   'w',
#   'f',
#   'dinola',
#   'a',
#   'haak',
#   'j',
#   'r'],
#  ['molecular', 'dynamics', 'with', 'coupling', 'to', 'an', 'external', 'bath'],
#  ['the', 'journal', 'of', 'chemical', 'physics'],
#  ['betz', 'r', 'm', 'dror', 'r', 'o'],
#  [],
#  ['how',
#   'effectively',
#   'can',
#   'adaptive',
#   'sampling',
#   'methods',
#   'capture',
#   'spontaneous',
#   'ligand',
#   'binding'],
#  ['journal',
#   'of',
#   'chemical',
#   'theory',
#   'and',
#   'computation',
#   'doi',
#   'christiansen',
#   'r',
#   'l',
#   'sloan',
#   'jr',
#   'e',
#   'd'],
#  ['mechanisms', 'and', 'kinetics', 'of', 'hydrate', 'formation'],
#  ['annals', 'of', 'the', 'new', 'york', 'academy', 'of', 'sciences'],
#  ['englezos', 'p'],
#  ['clathrate', 'hydrates'],
#  ['industrial',
#   'engineering',
#   'chemistry',
#   'research',
#   'doi',
#   'herzog',
#   'h',
#   'caldeira',
#   'k',
#   'adams',
#   'e'],
#  ['carbon', 'sequestration', 'via', 'direct', 'injection'],
#  ['encyclopedia', 'of', 'ocean', 'sciences'],
#  ['jacobson', 'l', 'c', 'hujo', 'w', 'molinero', 'v'],
#  [],
#  ['thermodynamic',
#   'stability',
#   'and',
#   'growth',
#   'of',
#   'guestfree',
#   'clathrate',
#   'hydrates',
#   'a',
#   'lowdensity',
#   'crystal',
#   'phase',
#   'of',
#   'water'],
#  ['the', 'journal', 'of', 'physical', 'chemistry', 'b'],
#  ['jacobson', 'l', 'c', 'hujo', 'w', 'molinero', 'v'],
#  [],
#  ['amorphous',
#   'precursors',
#   'in',
#   'the',
#   'nucleation',
#   'of',
#   'clathrate',
#   'hydrates'],
#  ['journal',
#   'of',
#   'the',
#   'american',
#   'chemical',
#   'society',
#   'doi',
#   'jiménezángeles',
#   'f',
#   'firoozabadi',
#   'a'],
#  [],
#  ['nucleation',
#   'of',
#   'methane',
#   'hydrates',
#   'at',
#   'moderate',
#   'subcooling',
#   'by',
#   'molecular',
#   'dynamics',
#   'simulations'],
#  ['the',
#   'journal',
#   'of',
#   'physical',
#   'chemistry',
#   'c',
#   'doi',
#   'urtec',
#   'jorgensen',
#   'w',
#   'l'],
#  ['optimized',
#   'intermolecular',
#   'potential',
#   'functions',
#   'for',
#   'liquid',
#   'alcohols'],
#  ['the', 'journal', 'of', 'physical', 'chemistry'],
#  ['jorgensen', 'w', 'l', 'madura', 'j', 'd', 'swenson', 'c', 'j'],
#  [],
#  ['optimized',
#   'intermolecular',
#   'potential',
#   'functions',
#   'for',
#   'liquid',
#   'hydrocarbons'],
#  ['journal', 'of', 'the', 'american', 'chemical', 'society'],
#  ['kashchiev', 'd', 'firoozabadi', 'a'],
#  [],
#  ['driving', 'force', 'for', 'crystallization', 'of', 'gas', 'hydrates'],
#  ['journal',
#   'of',
#   'crystal',
#   'growth',
#   'doi',
#   'https',
#   'lenz',
#   'a',
#   'ojamäe',
#   'l'],
#  ['structures',
#   'of',
#   'the',
#   'i',
#   'iiand',
#   'hmethane',
#   'clathrates',
#   'and',
#   'the',
#   'methane',
#   'clathrate',
#   'phase',
#   'transition',
#   'from',
#   'quantumchemical',
#   'modeling',
#   'with',
#   'forcefield',
#   'thermal',
#   'corrections'],
#  ['the', 'journal', 'of', 'physical', 'chemistry', 'a'],
#  ['levitt', 'm', 'hirshberg', 'm', 'sharon', 'r', 'daggett', 'v'],
#  [],
#  ['potential',
#   'energy',
#   'function',
#   'and',
#   'parameters',
#   'for',
#   'simulations',
#   'of',
#   'the',
#   'molecular',
#   'dynamics',
#   'of',
#   'proteins',
#   'and',
#   'nucleic',
#   'acids',
#   'in',
#   'solution'],
#  ['computer', 'physics', 'communications'],
#  ['li',
#   'l',
#   'zhong',
#   'j',
#   'yan',
#   'y',
#   'zhang',
#   'j',
#   'xu',
#   'j',
#   'francisco',
#   'j',
#   's',
#   'zeng',
#   'x',
#   'c'],
#  ['unraveling',
#   'nucleation',
#   'pathway',
#   'in',
#   'methane',
#   'clathrate',
#   'formation'],
#  ['proceedings', 'of', 'the', 'national', 'academy', 'of', 'sciences'],
#  ['liu', 's'],
#  ['molecular',
#   'dynamics',
#   'study',
#   'of',
#   'the',
#   'nucleation',
#   'of',
#   'binary',
#   'hydrate'],
#  ['mao', 'w', 'l', 'mao', 'hk', 'goncharov', 'a', 'f', 'struzhkin', 'v'],
#  ['v', 'guo', 'q', 'hu', 'j'],
#  [],
#  [],
#  ['zhao', 'y'],
#  [],
#  ['hydrogen', 'clusters', 'in', 'clathrate', 'hydrate'],
#  ['science', 'doi', 'martyna', 'g', 'j', 'klein', 'm', 'l', 'tuckerman', 'm'],
#  ['chains', 'the', 'canonical', 'ensemble', 'via', 'continuous', 'dynamics'],
#  ['the', 'journal', 'of', 'chemical', 'physics'],
#  ['matsunaga', 'y', 'sugita', 'y'],
#  [],
#  ['linking',
#   'timeseries',
#   'of',
#   'singlemolecule',
#   'experiments',
#   'with',
#   'molecular',
#   'dynamics',
#   'simulations',
#   'by',
#   'machine',
#   'learning'],
#  ['elife'],
#  ['mohr', 'p', 'j'],
#  [],
#  ['lamb', 'shift', 'in', 'a', 'strong', 'coulomb', 'potential'],
#  ['physical', 'review', 'letters'],
#  ['noé', 'f'],
#  ['machine',
#   'learning',
#   'for',
#   'molecular',
#   'dynamics',
#   'on',
#   'long',
#   'timescales'],
#  ['in', 'k', 't', 's', 'chmiela', 'o'],
#  ['a', 'von', 'lilienfeld', 'a', 'tkatchenko', 'k', 'tsuda', 'kr', 'eds'],
#  ['machine', 'learning', 'meets', 'quantum', 'physics', 'pp'],
#  [],
#  ['cham', 'springer', 'international', 'publishing'],
#  ['noé', 'f', 'tkatchenko', 'a', 'müller', 'kr', 'clementi', 'c'],
#  ['machine', 'learning', 'for', 'molecular', 'simulation'],
#  ['annual', 'review', 'of', 'physical', 'chemistry', 'doi', 'pande', 'v'],
#  ['s', 'beauchamp', 'k', 'bowman', 'g', 'r'],
#  ['everything',
#   'you',
#   'wanted',
#   'to',
#   'know',
#   'about',
#   'markov',
#   'state',
#   'models',
#   'but',
#   'were',
#   'afraid',
#   'to',
#   'ask'],
#  ['methods',
#   'doi',
#   'https',
#   'perrin',
#   'a',
#   'musa',
#   'o',
#   'm',
#   'steed',
#   'j',
#   'w'],
#  ['the',
#   'chemistry',
#   'of',
#   'low',
#   'dosage',
#   'clathrate',
#   'hydrate',
#   'inhibitors'],
#  ['chemical', 'society', 'reviews'],
#  ['prinz',
#   'jh',
#   'wu',
#   'h',
#   'sarich',
#   'm',
#   'keller',
#   'b',
#   'senne',
#   'm',
#   'held',
#   'm'],
#  [],
#  [],
#  ['noé', 'f'],
#  ['markov',
#   'models',
#   'of',
#   'molecular',
#   'kinetics',
#   'generation',
#   'and',
#   'validation'],
#  ['the', 'journal', 'of', 'chemical', 'physics'],
#  ['röblitz', 's', 'weber', 'm'],
#  ['fuzzy',
#   'spectral',
#   'clustering',
#   'by',
#   'pcca',
# ...
#   'friction',
#   'reducers',
#   'can',
#   'reach',
#   'nearly',
#   'friction',
#   'reduction',
#   'but',
#   'as',
#   'the',
#   'fluid',
#   'shears',
#   'down',
#   'the',
#   'full',
#   'residence',
#   'time',
#   'of',
#   'the',
#   'pipe',
#   'effective',
#   'friction',
#   'reduction',
#   'across',
#   'the',
#   'entire',
#   'pipe',
#   'length',
#   'is',
#   'several',
#   'percentage',
#   'points',
#   'lower'],
#  ['some',
#   'of',
#   'the',
#   'worstinclass',
#   'friction',
#   'reducers',
#   'provide',
#   'only',
#   'peak',
#   'friction',
#   'reduction'],
#  ['in',
#   'summary',
#   'pipe',
#   'id',
#   'pipe',
#   'length',
#   'stimulation',
#   'rate',
#   'and',
#   'friction',
#   'reducer',
#   'selection',
#   'are',
#   'very',
#   'important',
#   'levers',
#   'for',
#   'keeping',
#   'friction',
#   'reducer',
#   'application',
#   'rates',
#   'as',
#   'low',
#   'as',
#   'possible'],
#  ['tribal',
#   'knowledge',
#   'from',
#   'the',
#   'past',
#   'provided',
#   'a',
#   'rule',
#   'of',
#   'thumb',
#   'that',
#   'treating',
#   'rates',
#   'need',
#   'to',
#   'be',
#   'to',
#   'bpm',
#   'per',
#   'perforation',
#   'for',
#   'limited',
#   'entry',
#   'job',
#   'designs',
#   'to',
#   'open',
#   'the',
#   'majority',
#   'of',
#   'the',
#   'perforations'],
#  ['use',
#   'of',
#   'the',
#   'orifice',
#   'flow',
#   'equation',
#   'has',
#   'increased',
#   'the',
#   'precision',
#   'of',
#   'perforating',
#   'operations'],
#  ['the', 'orifice', 'flow', 'equation', 'is', 'as', 'follows', '𝑑𝑃𝑝'],
#  ['where',
#   'dp',
#   'total',
#   'perforation',
#   'friction',
#   'in',
#   'psi',
#   '𝑝',
#   'fluid',
#   'density',
#   'in',
#   'lbgallon',
#   'q',
#   'flow',
#   'rate',
#   'in',
#   'bpm',
#   'per',
#   'perforation',
#   'd',
#   'perforation',
#   'diameter',
#   'in',
#   'inches',
#   'c',
#   'discharge',
#   'coefficient',
#   'perforation',
#   'coefficient',
#   'coefficient',
#   'of',
#   'roundness',
#   'utilizing',
#   'the',
#   'orifice',
#   'flow',
#   'equation',
#   'for',
#   'a',
#   'diameter',
#   'perforation',
#   'using',
#   'standard',
#   'water',
#   'density',
#   'and',
#   'a',
#   'discharge',
#   'coefficient',
#   'the',
#   'perforation',
#   'pressure',
#   'drop',
#   'is',
#   'psi',
#   'for',
#   'a',
#   'bpm',
#   'treating',
#   'rate',
#   'and',
#   'psi',
#   'for',
#   'bpm',
#   'treating',
#   'rate'],
#  ['for',
#   'a',
#   'diameter',
#   'perforation',
#   'using',
#   'standard',
#   'water',
#   'density',
#   'and',
#   'discharge',
#   'coefficient',
#   'the',
#   'perforation',
#   'pressure',
#   'drop',
#   'is',
#   'psi',
#   'for',
#   'a',
#   'bpm',
#   'treating',
#   'rate',
#   'and',
#   'psi',
#   'for',
#   'a',
#   'bpm',
#   'treating',
#   'rate'],
#  ['these',
#   'relatively',
#   'low',
#   'modeled',
#   'pressure',
#   'drops',
#   'seem',
#   'to',
#   'have',
#   'minimal',
#   'impact',
#   'on',
#   'surface',
#   'horsepower',
#   'requirements'],
#  ['however',
#   'more',
#   'attention',
#   'is',
#   'being',
#   'paid',
#   'to',
#   'perforation',
#   'reliability',
#   'and',
#   'coefficient',
#   'of',
#   'roundness',
#   'and',
#   'for',
#   'good',
#   'reason'],
#  ['for',
#   'example',
#   'if',
#   'a',
#   'perf',
#   'gun',
#   'centralizer',
#   'is',
#   'not',
#   'used',
#   'or',
#   'vertical',
#   'phasing',
#   'deployed',
#   'slotted',
#   'perforations',
#   'can',
#   'be',
#   'created',
#   'instead',
#   'of',
#   'round',
#   'ones',
#   'as',
#   'the',
#   'perforating',
#   'gun',
#   'lifts',
#   'off',
#   'the',
#   'bottom',
#   'of',
#   'the',
#   'casing'],
#  ['for',
#   'the',
#   'perf',
#   'diameter',
#   'case',
#   'at',
#   'bpm',
#   'and',
#   'a',
#   'coefficient',
#   'of',
#   'roundness',
#   'reduced',
#   'to',
#   'the',
#   'calculated',
#   'pressure',
#   'drop',
#   'is',
#   'psi'],
#  ['operators',
#   'can',
#   'obtain',
#   'a',
#   'specific',
#   'hole',
#   'size',
#   'of',
#   'their',
#   'request',
#   'within',
#   'about',
#   'inches',
#   'snider'],
#  ['the',
#   'friction',
#   'reducer',
#   'is',
#   'typically',
#   'blamed',
#   'first',
#   'when',
#   'jobs',
#   'fail',
#   'to',
#   'pump'],
#  ['questions',
#   'of',
#   'friction',
#   'reducer',
#   'performance',
#   'are',
#   'eliminated',
#   'when',
#   'products',
#   'are',
#   'selected',
#   'and',
#   'quality',
#   'checked',
#   'by',
#   'the',
#   'technology',
#   'embodied',
#   'in',
#   'patent',
#   'number',
#   'us',
#   'svarczkopf'],
#  ['frac',
#   'gradient',
#   'is',
#   'also',
#   'regularly',
#   'blamed',
#   'when',
#   'jobs',
#   'won',
#   't',
#   'pump'],
#  ['in',
#   'reality',
#   'perforation',
#   'reliability',
#   'is',
#   'often',
#   'causal',
#   'to',
#   'difficult',
#   'job',
#   'placement'],
#  ['perforating',
#   'charge',
#   'specification',
#   'and',
#   'cluster',
#   'design',
#   'can',
#   'be',
#   'significant',
#   'levers',
#   'for',
#   'reducing',
#   'surface',
#   'horsepower',
#   'and',
#   'friction',
#   'reducer',
#   'requirements'],
#  ['fluids',
#   'following',
#   'the',
#   'urtec',
#   'path',
#   'of',
#   'least',
#   'resistance',
#   'is',
#   'a',
#   'commonly',
#   'understood',
#   'hydraulic',
#   'engineering',
#   'principle'],
#  ['the',
#   'industry',
#   'clearly',
#   'observes',
#   'this',
#   'phenomena',
#   'when',
#   'frac',
#   'hits',
#   'happen',
#   'miles',
#   'from',
#   'a',
#   'well',
#   'bore',
#   'being',
#   'fracture',
#   'stimulated'],
#  ['fluids',
#   'preferentially',
#   'flow',
#   'to',
#   'the',
#   'connected',
#   'porosity',
#   'andor',
#   'natural',
#   'fracture',
#   'swarms'],
#  ['once',
#   'pipe',
#   'pressure',
#   'during',
#   'fracturing',
#   'is',
#   'equalized',
#   'flow',
#   'will',
#   'tend',
#   'to',
#   'go',
#   'through',
#   'those',
#   'clusters',
#   'offering',
#   'the',
#   'least',
#   'resistance',
#   'preferentially'],
#  ['since',
#   'pipe',
#   'friction',
#   'can',
#   'be',
#   'as',
#   'high',
#   'as',
#   'psifoot',
#   'foot',
#   'spacing',
#   'of',
#   'clusters',
#   'can',
#   'result',
#   'in',
#   'the',
#   'perf',
#   'clusters',
#   'furthest',
#   'from',
#   'the',
#   'pump',
#   'having',
#   'psi',
#   'reduced',
#   'pressure',
#   'force',
#   'for',
#   'opening',
#   'perforations'],
#  ['given',
#   'the',
#   'possibility',
#   'it',
#   'doesn',
#   't',
#   'seem',
#   'wise',
#   'to',
#   'engineer',
#   'all',
#   'clusters',
#   'along',
#   'a',
#   'foot',
#   'lateral',
#   'section',
#   'equally'],
#  ['fewer',
#   'perforations',
#   'in',
#   'clusters',
#   'closest',
#   'to',
#   'the',
#   'pump',
#   'would',
#   'seem',
#   'to',
#   'give',
#   'those',
#   'clusters',
#   'furthest',
#   'from',
#   'the',
#   'pump',
#   'a',
#   'better',
#   'opportunity',
#   'to',
#   'receive',
#   'fluid'],
#  ['an',
#   'example',
#   'perf',
#   'cluster',
#   'configuration',
#   'to',
#   'more',
#   'equally',
#   'distribute',
#   'flow',
#   'across',
#   'feet',
#   'of',
#   'lateral',
#   'is',
#   'provided',
#   'in',
#   'fig'],
#  [],
#  ['frac',
#   'pumps',
#   'perfs',
#   'perfs',
#   'perfs',
#   'perfs',
#   'perfs',
#   'perfs',
#   'perfs',
#   'perfs',
#   'acid',
#   'breakdown',
#   'of',
#   'calcareous',
#   'formations',
#   'create',
#   'fracture',
#   'initiation',
#   'sites',
#   'and',
#   'reduce',
#   'near',
#   'well',
#   'tortuosity'],
#  ['this',
#   'lowers',
#   'surface',
#   'horsepower',
#   'and',
#   'friction',
#   'reducer',
#   'demand'],
#  ['sand',
#   'placement',
#   'designs',
#   'can',
#   'also',
#   'affect',
#   'friction',
#   'reducer',
#   'and',
#   'horsepower',
#   'requirements'],
#  ['the',
#   'viscosity',
#   'of',
#   'a',
#   'fluid',
#   'required',
#   'to',
#   'place',
#   'a',
#   'ppg',
#   'sand',
#   'concentration',
#   'fluid',
#   'is',
#   'far',
#   'different',
#   'than',
#   'one',
#   'required',
#   'to',
#   'place',
#   'a',
#   'peak',
#   'ppg',
#   'sand',
#   'concentration'],
#  ['fluid',
#   'friction',
#   'reducer',
#   'requirements',
#   'also',
#   'increase',
#   'when',
#   'tailing',
#   'in',
#   'with',
#   'and',
#   'coarser',
#   'sands'],
#  ['there',
#   'is',
#   'an',
#   'optimal',
#   'fluid',
#   'viscosity',
#   'that',
#   'must',
#   'be',
#   'available',
#   'at',
#   'the',
#   'perforation',
#   'to',
#   'transport',
#   'sand'],
#  ['if',
#   'there',
#   'is',
#   'too',
#   'little',
#   'fluid',
#   'viscosity',
#   'fluid',
#   'leak',
#   'off',
#   'into',
#   'natural',
#   'micro',
#   'swarm',
#   'fractures',
#   'occurs',
#   'causing',
#   'sand',
#   'duning'],
#  ['this',
#   'results',
#   'in',
#   'higher',
#   'horsepower',
#   'requirements',
#   'and',
#   'difficult',
#   'job',
#   'placement'],
#  ['if',
#   'the',
#   'fluid',
#   'viscosity',
#   'is',
#   'too',
#   'high',
#   'sand',
#   'bridging',
#   'across',
#   'far',
#   'field',
#   'micro',
#   'fractures',
#   'occurs',
#   'which',
#   'increases',
#   'treating',
#   'pressures',
#   'in',
#   'order',
#   'to',
#   'move',
#   'fluid',
#   'into',
#   'distant',
#   'fractures'],
#  ['depending',
#   'on',
#   'job',
#   'design',
#   'and',
#   'friction',
#   'reducer',
#   'type',
#   'the',
#   'optimal',
#   'viscosity',
#   'build',
#   'ranges',
#   'between',
#   'a',
#   'to',
#   'increase',
#   'over',
#   'the',
#   'baseline',
#   'fluid',
#   'available',
#   'at',
#   'the',
#   'perf',
#   'based',
#   'on',
#   'years',
#   'of',
#   'data',
#   'generated',
#   'by',
#   'the',
#   'technology',
#   'embodied',
#   'in',
#   'patent',
#   'number',
#   'us'],
#  ['case',
#   'history',
#   'hibernia',
#   'mary',
#   'rose',
#   'pad',
#   'versus',
#   'james',
#   'pad',
#   'wolfcamp',
#   'upper',
#   'b',
#   'formation',
#   'target',
#   'the',
#   'james',
#   'pad',
#   'is',
#   'adjacent',
#   'to',
#   'the',
#   'hibernia',
#   'mary',
#   'rose',
#   'pad',
#   'in',
#   'reagan',
#   'county',
#   'texas'],
#  ['the',
#   'pads',
#   'are',
#   'suitable',
#   'for',
#   'benchmarking',
#   'the',
#   'wolfcamp',
#   'upper',
#   'b',
#   'and',
#   'wolfcamp',
#   'lower',
#   'b',
#   'formation',
#   'targets'],
#  ['a', 'gun', 'barrel', 'diagram', 'follows', 'as', 'fig'],
#  [],
#  ['figure'],
#  ['gun',
#   'barrel',
#   'diagram',
#   'depicting',
#   'the',
#   'wells',
#   'of',
#   'the',
#   'hibernia',
#   'mary',
#   'rose',
#   'and',
#   'adjacent',
#   'james',
#   'pads'],
#  ['figure'],
#  ['an', 'example', 'of', 'optimal', 'perf', 'cluster', 'distribution'],
#  ['urtec',
#   'this',
#   'case',
#   'history',
#   'compares',
#   'wolfcamp',
#   'upper',
#   'b',
#   'formation',
#   'target',
#   'wells'],
#  ['the',
#   'james',
#   'n',
#   'well',
#   'represents',
#   'the',
#   'parent',
#   'well',
#   'for',
#   'the',
#   'wolfcamp',
#   'upper',
#   'b',
#   'formation',
#   'for',
#   'the',
#   'area'],
#  ['the',
#   'remainder',
#   'of',
#   'all',
#   'wells',
#   'compared',
#   'are',
#   'child',
#   'wells'],
#  ['the',
#   'imperative',
#   'chemical',
#   'partners',
#   'optimized',
#   'pore',
#   'throat',
#   'investigations',
#   'and',
#   'solutions',
#   'optis',
#   'proprietary',
#   'laboratory',
#   'workflow',
#   'and',
#   'patented',
#   'methods',
#   'were',
#   'utilized',
#   'to',
#   'select',
#   'the',
#   'optimal',
#   'fluid',
#   'package',
#   'for',
#   'the',
#   'hibernia',
#   'mary',
#   'rose',
#   'wells'],
#  ['even',
#   'though',
#   'fresh',
#   'water',
#   'was',
#   'utilized',
#   'for',
#   'the',
#   'mary',
#   'rose',
#   'wells',
#   'a',
#   'solids',
#   'slurry',
#   'amps',
#   'terpolymer',
#   'friction',
#   'reducer',
#   'was',
#   'deployed',
#   'based',
#   'on',
#   'skin',
#   'damage',
#   'experimental',
#   'results'],
#  ['the',
#   'fluid',
#   'goal',
#   'was',
#   'to',
#   'maintain',
#   'friction',
#   'reducer',
#   'treating',
#   'rates',
#   'as',
#   'low',
#   'as',
#   'possible'],
#  ['other',
#   'fluid',
#   'package',
#   'components',
#   'specified',
#   'were',
#   'a',
#   'gallons',
#   'per',
#   'stage'],
#  ['b', 'gpt', 'solvent', 'based', 'nesdr'],
#  ['c',
#   'gpt',
#   'polyacrylate',
#   'based',
#   'scale',
#   'inhibitor',
#   'and',
#   'd',
#   'gpt',
#   'glutaraldehyde',
#   'based',
#   'friction',
#   'reducer'],
#  ['the', 'friction', 'reducer', 'treating', 'rates', 'fig'],
#  ['were',
#   'kept',
#   'very',
#   'low',
#   'at',
#   'gpt',
#   'as',
#   'was',
#   'predicted',
#   'by',
#   'the',
#   'patented',
#   'friction',
#   'flow',
#   'loop'],
#  ['figure'],
#  ['mary',
#   'rose',
#   'stage',
#   'plot',
#   'confirms',
#   'low',
#   'friction',
#   'reducer',
#   'treat',
#   'rate',
#   'necessary',
#   'to',
#   'effectively',
#   'place',
#   'job'],
#  ['table'],
#  ['mary', 'rose', 'job', 'placement', 'design', 'targets'],
#  ['stage',
#   'spacing',
#   'ft',
#   'sand',
#   'loading',
#   'lbfoot',
#   'max',
#   'sand',
#   'concentration',
#   'ppg',
#   'fluid',
#   'loading',
#   'bblfoot',
#   'treating',
#   'rate',
#   'bpm',
#   'perf',
#   'cluster',
#   'per',
#   'stage',
#   'perfs',
#   'per',
#   'cluster',
#   'perf',
#   'phasing',
#   'degrees',
#   'perf',
#   'diameter',
#   'inches',
#   'perf',
#   'charge',
#   'type',
#   'equihole',
#   'geofrac',
#   'iq',
#   'other',
#   'benchmarking',
#   'data',
#   'relative',
#   'to',
#   'the',
#   'james',
#   'pad',
#   'wells',
#   'post',
#   'completion',
#   'are',
#   'table'],
#  ['benchmarking', 'data', 'of', 'mary', 'rose', 'and', 'james', 'wells'],
#  ['well',
#   'lateral',
#   'length',
#   'ft',
#   'sand',
#   'loading',
#   'lbfoot',
#   'fluid',
#   'loading',
#   'bblfoot',
#   'mary',
#   'rose',
#   'a',
#   'mary',
#   'rose',
#   'c',
#   'james',
#   'a',
#   'james',
#   'd',
#   'james',
#   'f',
#   'james',
#   'i',
#   'james',
#   'k',
#   'james',
#   'n',
#   'urtec',
#   'figure'],
#  ['various',
#   'well',
#   'productivity',
#   'metrics',
#   'of',
#   'upper',
#   'wolfcamp',
#   'b',
#   'mary',
#   'rose',
#   'and',
#   'upper',
#   'wolfcamp',
#   'b',
#   'james',
#   'wells'],
#  ['well',
#   'productivity',
#   'metrics',
#   'normalized',
#   'to',
#   'foot',
#   'lateral',
#   'length',
#   'are',
#   'a',
#   'cumulative',
#   'well',
#   'oil',
#   'production'],
#  ['b', 'cumulative', 'well', 'gas', 'production'],
#  ['c', 'cumulative', 'well', 'water', 'production'],
#  ['d', 'cumulative', 'total', 'fluid', 'oil', 'and', 'water'],
#  ['all',
#   'production',
#   'data',
#   'is',
#   'pulled',
#   'from',
#   'enverus',
#   'and',
#   'reported',
#   'without',
#   'manipulation',
#   'besides',
#   'lateral',
#   'length',
#   'normalization',
#   'to',
#   'feet'],
#  ['table'],
#  ['oil',
#   'and',
#   'gas',
#   'eur',
#   'data',
#   'for',
#   'mary',
#   'rose',
#   'and',
#   'james',
#   'upper',
#   'wolfcamp',
#   'b',
#   'wells',
#   'calculated',
#   'by',
#   'enverus'],
#  ['well',
#   'eur',
#   'monetary',
#   'value',
#   'calculated',
#   'using',
#   'a',
#   'oil',
#   'and',
#   'gas',
#   'price',
#   'deck'],
#  ['well',
#   'oil',
#   'eur',
#   'bbl',
#   'gas',
#   'eur',
#   'mcf',
#   'well',
#   'eur',
#   'value',
#   'usd',
#   'average',
#   'upper',
#   'wcb',
#   'eur',
#   'value',
#   'usd',
#   'mary',
#   'rose',
#   'a',
#   'mary',
#   'rose',
#   'c',
#   'james',
#   'a',
#   'james',
#   'd',
#   'james',
#   'f',
#   'james',
#   'i',
#   'james',
#   'k',
#   'james',
#   'n',
#   'note',
#   'eur',
#   'values',
#   'calculated',
#   'using',
#   'a',
#   'oil',
#   'and',
#   'price',
#   'deck'],
#  ['based',
#   'on',
#   'the',
#   'data',
#   'the',
#   'following',
#   'conclusions',
#   'are',
#   'offered',
#   'after',
#   'months',
#   'the',
#   'hibernia',
#   'mary',
#   'rose',
#   'wolfcamp',
#   'upper',
#   'b',
#   'wells',
#   'averaged',
#   'bbl',
#   'of',
#   'cumulative',
#   'oil',
#   'production',
#   'per',
#   'well',
#   'fig'],
#  [],
#  ['after',
#   'months',
#   'james',
#   'wolfcamp',
#   'upper',
#   'b',
#   'wells',
#   'averaged',
#   'bbl',
#   'of',
#   'cumulative',
#   'oil',
#   'production',
#   'per',
#   'well',
#   'inclusive',
#   'of',
#   'the',
#   'n',
#   'parent',
#   'well',
#   'fig'],
#  [],
#  ['after',
#   'months',
#   'the',
#   'hibernia',
#   'mary',
#   'rose',
#   'wolfcamp',
#   'upper',
#   'b',
#   'wells',
#   'produced',
#   'an',
#   'average',
#   'of',
#   'bbl',
#   'additional',
#   'oil',
#   'per',
#   'well',
#   'over',
#   'the',
#   'james',
#   'wells'],
#  ['at',
#   'a',
#   'per',
#   'bbl',
#   'price',
#   'deck',
#   'this',
#   'represents',
#   'an',
#   'increased',
#   'value',
#   'of',
#   'per',
#   'well',
#   'within',
#   'the',
#   'first',
#   'months',
#   'fig'],
#  [],
#  ['urtec',
#   'enverus',
#   'calculated',
#   'eur',
#   'data',
#   'results',
#   'in',
#   'a',
#   'predicted',
#   'lifetime',
#   'economic',
#   'value',
#   'of',
#   'for',
#   'mary',
#   'rose',
#   'wolfcamp',
#   'upper',
#   'b',
#   'wells',
#   'versus',
#   'for',
#   'james',
#   'wolfcamp',
#   'upper',
#   'b',
#   'wells',
#   'at',
#   'a',
#   'price',
#   'deck',
#   'of',
#   'for',
#   'oil',
#   'and',
#   'natural',
#   'gas',
#   'table'],
#  ['potential',
#   'rationale',
#   'for',
#   'the',
#   'increased',
#   'hibernia',
#   'mary',
#   'rose',
#   'wolfcamp',
#   'upper',
#   'well',
#   'productivity',
#   'a',
#   'vastly',
#   'different',
#   'completion',
#   'fluids',
#   'were',
#   'utilized',
#   'on',
#   'the',
#   'mary',
#   'rose',
#   'wells'],
#  ['b',
#   'different',
#   'perf',
#   'cluster',
#   'designs',
#   'were',
#   'utilized',
#   'to',
#   'complete',
#   'the',
#   'mary',
#   'rose',
#   'wells',
#   'table'],
#  ['c',
#   'sand',
#   'loadings',
#   'were',
#   'lower',
#   'for',
#   'three',
#   'of',
#   'the',
#   'six',
#   'james',
#   'wells'],
#  ['however',
#   'the',
#   'three',
#   'james',
#   'wells',
#   'with',
#   'similar',
#   'sand',
#   'loadings',
#   'to',
#   'the',
#   'mary',
#   'rose',
#   'wells',
#   'performed',
#   'poorly',
#   'in',
#   'comparison',
#   'especially',
#   'given',
#   'that',
#   'one',
#   'of',
#   'the',
#   'wells',
#   'was',
#   'a',
#   'parent',
#   'well',
#   'table'],
#  ...]

# %%
custom_model = Word2Vec(processed_text, min_count=3, vector_size=300, workers=10, window=7, epochs=200)

# %%
custom_model.save('urtec.model')

# %%
custom_model.wv.most_similar('frac', topn=10)
# Out:
# [('fracture', 0.37705597281455994),
#  ('well', 0.3348378539085388),
#  ('completion', 0.3298324644565582),
#  ('prefrac', 0.3199969530105591),
#  ('stimulation', 0.31596657633781433),
#  ('diminish', 0.2915516793727875),
#  ('rac', 0.2768298387527466),
#  ('fracturing', 0.27543920278549194),
#  ('parent', 0.27295905351638794),
#  ('fractures', 0.2691037952899933)]

# %%
custom_model = Word2Vec.load('urtec.model')

# %%
custom_model.wv.most_similar('frac', topn=10)
# Out:
# [('fracture', 0.37705597281455994),
#  ('well', 0.3348378539085388),
#  ('completion', 0.3298324644565582),
#  ('prefrac', 0.3199969530105591),
#  ('stimulation', 0.31596657633781433),
#  ('diminish', 0.2915516793727875),
#  ('rac', 0.2768298387527466),
#  ('fracturing', 0.27543920278549194),
#  ('parent', 0.27295905351638794),
#  ('fractures', 0.2691037952899933)]

# %%
# Get the word vectors
word_vectors = custom_model.wv.vectors

# Use UMAP to reduce dimensions
umap_data = umap.UMAP(n_neighbors=5, min_dist=0.3, n_components=2).fit_transform(word_vectors)

# %%
# Prepare data for the plot
trace = go.Scatter(
    x = umap_data[:,0],
    y = umap_data[:,1],
    mode = 'markers',
    text = custom_model.wv.index_to_key,  # This will be displayed when a point is hovered over
    marker = dict(
        color = '#FFBAD2',
        line = dict(width = 1)
    )
)

# Define the layout
layout = go.Layout(
    title='Word Embeddings',
    xaxis=dict(title='UMAP Dimension 1'),
    yaxis=dict(title='UMAP Dimension 2')
)

# Define the figure
fig = go.Figure(data=[trace], layout=layout)

# Render the plot
fig.show()
# Out:
# <div>                            <div id="eafd1a20-f21f-4e1b-97c2-f49c635b71ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eafd1a20-f21f-4e1b-97c2-f49c635b71ee")) {                    Plotly.newPlot(                        "eafd1a20-f21f-4e1b-97c2-f49c635b71ee",                        [{"marker":{"color":"#FFBAD2","line":{"width":1}},"mode":"markers","text":["the","and","of","in","to","a","is","for","with","well","this","from","as","on","that","by","fracture","figure","wells","production","are","at","was","pressure","urtec","s","data","oil","be","gas","al","et","model","reservoir","an","can","were","or","water","using","not","unconventional","we","which","b","shale","fluid","used","it","flow","time","between","m","results","fractures","analysis","j","d","c","https","rock","hydraulic","have","paper","study","these","rate","formation","any","t","basin","each","more","than","based","during","all","conference","injection","information","has","fracturing","technology","different","reservoirs","field","volume","stress","r","also","after","permeability","simulation","fig","performance","spe","p","case","other","e","presented","properties","high","horizontal","been","two","h","into","parent","frac","resources","shows","stage","development","both","completion","shown","proppant","when","where","recovery","distribution","values","method","due","samples","their","area","observed","parameters","pore","design","one","models","total","natural","core","table","lower","strain","higher","such","f","within","k","initial","spacing","y","does","first","sample","vertical","however","through","g","child","while","three","no","but","wellbore","change","only","ft","impact","process","history","l","surface","conditions","n","system","workflow","average","value","i","storage","texas","stimulation","test","phase","approach","will","over","may","new","same","length","along","measurements","increase","porosity","low","usa","most","modeling","fiber","zone","potential","temperature","there","ratio","x","changes","co","cluster","its","petroleum","matrix","obtained","plot","type","section","effect","then","compared","drilling","w","lateral","author","log","energy","conductivity","number","rates","ford","surfactant","eagle","under","cumulative","produced","organic","ms","per","methods","work","behavior","our","psi","doi","depletion","show","o","wolfcamp","source","saturation","set","stages","use","significant","without","curve","size","including","monitoring","decline","treatment","response","density","would","seismic","hydrocarbon","learning","depth","technical","solution","effective","single","measured","multiple","comparison","less","vs","if","eur","could","relative","liquid","point","bakken","some","fluids","drainage","calculated","similar","effects","accuracy","permian","part","applied","developed","variable","example","content","result","linear","optimization","key","rocks","so","match","geological","play","range","function","factors","formations","equation","exhibition","provide","complex","v","factor","evaluation","target","upper","herein","following","carbonate","tight","us","across","large","they","period","engineering","various","maximum","abstract","journal","characterization","interference","up","understanding","better","efficiency","further","facies","available","network","primary","before","present","hydrogen","quality","several","important","respectively","areas","carbon","presentation","constant","height","cases","midland","fdi","near","given","kerogen","application","how","increased","algorithm","associated","clay","systems","perforation","days","considered","below","increasing","zones","about","productivity","clusters","geometry","right","fractured","chemical","above","very","left","provides","profile" ...

# %%
# Define words
words = ['feynman', 'physics', 'data', 'intelligence']

# Get the top 20 most similar words to each word in the list
similar_words = [custom_model.wv.most_similar(word, topn=20) for word in words]

# Flatten the list of similar words and add the original words
all_words = [word for similar in similar_words for word, _ in similar] + words

# Get the vectors for each word
all_vectors = custom_model.wv[all_words]

# Reduce dimensionality
umap_data = umap.UMAP(n_neighbors=5, min_dist=0.3, n_components=2).fit_transform(all_vectors)

# Prepare traces for the plot
traces = []
for i, word in enumerate(words):
    # Get the UMAP coordinates for the original word and its similar words
    x = umap_data[i*21:(i+1)*21, 0]
    y = umap_data[i*21:(i+1)*21, 1]
    # Create a trace for this word
    trace = go.Scatter(
        x = x,
        y = y,
        mode = 'markers',
        name = word,
        text = all_words[i*21:(i+1)*21],  # This will be displayed when a point is hovered over
        marker = dict(
            size = 10,
            line = dict(width = 1)
        )
    )
    traces.append(trace)

# Define the layout
layout = go.Layout(
    title='Word Embeddings',
    xaxis=dict(title='UMAP Dimension 1'),
    yaxis=dict(title='UMAP Dimension 2')
)

# Define the figure
fig = go.Figure(data=traces, layout=layout)

# Render the plot
fig.show()
# Out:
# <div>                            <div id="8170c678-5b7b-4993-be27-6fd5715e4c8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8170c678-5b7b-4993-be27-6fd5715e4c8a")) {                    Plotly.newPlot(                        "8170c678-5b7b-4993-be27-6fd5715e4c8a",                        [{"marker":{"line":{"width":1},"size":10},"mode":"markers","name":"feynman","text":["lectures","fluidrock","lennardjones","prithvi","informati","saberi","relying","presentati","ely","othe","hamzeh","cwc","nformati","omnilogs","ener","acting","downloaded","adsorpti","cluste","soc","peridynamics"],"x":[6.451801,6.524226,5.893658,5.4764175,6.715256,6.792188,6.127705,6.5537853,6.734883,5.26931,7.2693357,6.326796,6.529423,7.0952477,7.5753775,6.2925,8.151996,6.9245944,7.0136313,6.58378,5.1997137],"y":[-0.096894704,0.6888218,1.5540657,3.2794259,-0.6096899,2.3655853,-0.61584383,-1.0903932,1.4594359,2.9327073,1.790445,1.0824955,-0.7597037,0.9575465,1.3799531,-0.39899656,1.2933393,-0.705789,1.9921386,2.9661922,3.9038985],"type":"scatter"},{"marker":{"line":{"width":1},"size":10},"mode":"markers","name":"physics","text":["coupled","mech","facts","approach","datadriven","barclay","carreau","numerical","glutaraldehyde","zonation","vosburgh","geomechanics","marini","method","learning","weathering","principles","toolbox","ratetransient","logs","measurements"],"x":[5.129726,5.8822317,7.385782,7.652713,5.3593574,6.041051,5.6240497,4.721284,6.8945465,6.3121066,6.440928,6.324858,6.2426033,7.8172784,3.4381845,5.8733296,6.9868426,7.3155537,6.6406817,8.28668,8.6298685],"y":[4.4307685,1.5132166,3.6136892,5.0814686,3.764702,1.8785604,4.5777454,3.9607248,3.9986835,3.490133,2.7184997,4.4902124,1.9829088,4.996062,1.785208,2.6005723,2.7969673,4.6874976,3.4119651,2.9367878,3.194721],"type":"scatter"},{"marker":{"line":{"width":1},"size":10},"mode":"markers","name":"data","text":["dataset","results","datasets","analysis","log","records","interpretations","calibrated","observations","history","information","predictions","gauges","derived","models","model","features","reports","neural","transforming","caverns"],"x":[8.123753,6.01025,5.5122166,6.801776,8.076968,7.0749264,6.15279,5.882046,6.8004937,7.1530533,6.8534346,7.685948,7.263199,8.412318,6.460501,6.8413463,5.2563357,7.7318606,3.7635415,6.407219,6.139517],"y":[1.4455891,2.9248207,1.9810593,2.274124,2.6877408,3.2902238,3.2749171,3.511422,3.6535294,2.980186,-0.12436003,3.8507383,1.2238537,1.4533486,5.0835986,5.0953813,1.2936525,3.2237518,3.3246026,2.1560922,2.4620829],"type":"scatter"},{"marker":{"line":{"width":1},"size":10},"mode":"markers","name":"intelligence","text":["isotrap","gpu","forest","automatic","automl","embedded","svm","edfm","nvidia","lstm","expanding","adaptive","learning","adaptation","gained","ai","advanced","feynman","physics","data","intelligence"],"x":[5.5164084,3.4329598,4.4361277,4.3638964,7.4138002,4.760471,4.0815496,4.919905,3.8209357,3.320801,4.3677444,4.5620723,3.469498,7.300008,5.3557916,5.6901035,4.019278,6.7072296,5.597857,8.292146,3.5228727],"y":[2.6320107,2.718393,2.937511,1.9472475,2.4800558,1.6465893,3.1051545,3.9446323,2.0835552,2.357878,1.6597654,3.3852062,1.8178262,2.3917117,2.2702618,2.7123122,2.3038902,0.4779725,4.213196,3.429484,2.8196628],"type":"scatter"}],                        {"title":{"text":"Word Embeddings"},"xaxis":{"title":{"text":"UMAP Dimension 1"}},"yaxis":{"title":{"text":"UMAP Dimension 2"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777777 ...

# %%
# Find the most similar words
similar_words = custom_model.wv.most_similar(positive=['machine', 'learning'], negative=['black', 'box'], topn=20)

for word, similarity in similar_words:
    print(word, similarity)
# Out:
# datadriven 0.26629921793937683
# intelligence 0.26172393560409546
# forecasting 0.2561148405075073
# recognition 0.2520157992839813
# neural 0.24715037643909454
# automatic 0.24380120635032654
# multivariate 0.241044819355011
# realtime 0.24044063687324524
# yuewei 0.2363181710243225
# mathematica 0.23421600461006165
# ml 0.2318514734506607
# engineering 0.22944073379039764
# novel 0.22687287628650665
# physics 0.22576506435871124
# traditional 0.22433049976825714
# automation 0.22026363015174866
# ness 0.21803973615169525
# tried 0.21603770554065704
# empirical 0.21584351360797882
# optimization 0.21554790437221527
